# %%
import pandas as pd
import random 
import matplotlib.pyplot as plt
from fuzzywuzzy import fuzz
from collections import defaultdict
from rdflib import Graph, Literal, Namespace, RDF, URIRef, BNode
import openai
import ast
import pickle
from urllib.parse import quote
from tqdm import tqdm

# %% [markdown]
# # Load the file ENTPTNERDOI.csv.tar.gz from https://zenodo.org/records/10022727

# %%
ENTDOI = pd.read_csv('ENTPTNERDOI.csv')

# %%
ENTDOI.sample(5)
# Out:
#              Entity Part_of_text NER_Tag                               DOI  \
# 7966059     calcium          Abs     CHM  10.1111/j.1551-2916.2006.01203.x
# 83090376     sulfur          Cap     CHM      10.1016/j.apsusc.2017.10.076
# 23313622     anodes          Abs     APL    10.1016/j.jpowsour.2014.07.081
# 39090930         p+          Abs     PRO     10.1016/s0169-4332(01)00526-8
# 22326316  catalysts          Abs     APL         10.1186/s11671-018-2824-7
#
#          Preferred_Entity    Year
# 7966059           Calcium  2006.0
# 83090376           Sulfur  2018.0
# 23313622           Anodes  2014.0
# 39090930               P+  2001.0
# 22326316         Catalyst  2018.0

# %% [markdown]
# ### Analysing ENTDOI.csv

# %%
print("Number of rows : {}".format(ENTDOI.shape[0]))
# Out:
# Number of rows : 84659831

# %% [markdown]
# ### Extracting all the raw entities for cleaning

# %% [markdown]
# Let's extract all raw entities

# %%
all_entities = list(set(ENTDOI['Entity'].tolist()))

# %%
print("Number of entities : {}".format(len(all_entities)))
# Out:
# Number of entities : 197623

# %% [markdown]
# Now, the entities are clubbed according to their Levenshtein distance

# %%
clusters = defaultdict(set)
threshold = 90
for entity in tqdm(entity_list, total = len(entity_list)):
    found = False
    for key in clusters.keys():
        if fuzz.ratio(key, entity) >= threshold:
            clusters[key].add(entity)
            found = True
            break
    if not found:
        clusters[entity].add(entity)

# %% [markdown]
# These clustered entities are cleaned using OpenAI API

# %% [markdown]
# ### Grouping and cleaning clusters using OpenAI

# %%
openai.api_key = '<enter api key>'

# %%
prompt = """
Given a list of scientific terms as input, return a list of normalized terms as output. The normalization should take into\
account minor spelling variations, plural forms, special characters, and word order. Additionally, the normalization should\
preserve distinctions in terms that have specific additional descriptors. Each input term should have a corresponding\
output term in title case.

Examples:
Input: ['nanobeam', 'nanobeams', 'gap activity', 'gpx activity', 'alp activity', 'vibration amplitude', 'vibration amplitudes',\
 'photo images', 'Photo images', 'photo image', 'pebbles', 'pebble', 'pressure drops', 'pressure - drop',\
 'dark-field image.']
Output: ['Nanobeam', 'Nanobeam', 'Gap Activity', 'GPX Activity', 'ALP Activity', 'Vibration Amplitude', 'Vibration Amplitude',\
 'Photo Images', 'Photo Images', 'Photo Images', 'Pebbles', 'Pebbles', 'Pressure Drop', 'Pressure Drop', 'Dark Field Image']
Please provide the output as a list for the given input terms
Input Terms:
{}
Output Terms:
"""

def return_prompt(input_):
    return prompt.format(input_)

# %%
mapping_dict = {}
failed_lists = []
final_list = [list(value) for key, value in clusters.items()]

# %%
for input_list in tqdm(final_lists, total = len(final_lists)):
    Run = True
    for x in input_list:
        if x in mapping_dict:
            Run = False
    try:
        if Run:
            response = openai.Completion.create(
                                model="text-davinci-003",
                                prompt = return_prompt(input_list),
                                max_tokens=1024,
                                temperature=0.1,
                            )
            result=response.choices[0].text
            result_list = ast.literal_eval(result)

            if len(result_list) == len(input_list):
                for A, B in zip(input_list, result_list):
                    mapping_dict[A] = B
            else:
                failed_lists.append([input_list, result_list])

            if random.random()<0.01:
                time.sleep(100)
                pickle.dump(mapping_dict, open('final_rdf_mapping_dict.pickle', 'wb'))
                pickle.dump(failed_lists, open('final_rdf_error_lists.pickle', 'wb'))
        else:
            continue
    except:
        failed_lists.append([input_list, result_list])

# %% [markdown]
# The mapping dict contains the (raw_entity, preferred_entity) pairings. \
# Note that many clusters have only value. These can be filtered to trim the number of API calls

# %%
all_pref = list(set(ENTDOI['Preferred_Entity'].tolist()))

# %%
count =0
for pref in all_pref:
    if pref not in mapping_dict:
        print(pref)
        count+=1
# Out:
# Molecular Symmetries
# Dynamic Melting
# Sillen
# (MnFe2O4)x
# Dry Eye
# Axis Sputtering
# Corneal Endothelium
# G″) Modulus
# ZnR2
# Spiro-2CBP
# Terpy-C6-SAc
# Demo Blanket
# HSAB
# Soft Metallic
# Zn Isotope Composition
# ICH3
# PdTPP
# GMS
# Initiated Oxidation
# Malondialdehyde Content
# Methionines
# Total Electronic Energy
# AISI 4140T Steel
# EMI Shielding Materials
# Tectono-Metamorphic
# Microlitic
# Pd(001)
# HgCl2–CaCO3
# Hydrogenolytic Activity
# K Min
# Total Carbon Concentration
# Electrolysis Voltage
# Si2p XPS
# Finite Size
# Elements Mappings
# CZA
# FMOC Deprotection
# Power Load
# Anticonvulsant Properties
# Pd(CH3COO)2
# BSZMN
# Li2RuO3
# iFC
# Transpassive
# Rump Simulation
# Leakage Risk
# MnGe
# HAADF-STEM-EDS Mappings
# As Plated
# Plant Community
# PTG
# Piezoelectric Semiconductor
# C-Heteroatom
# Imaginary ε''
# Label-Free Biosensor
# Hydrodynamic Amperometry
# Booklets
# Resiniferatoxin
# Ammonia Adsorption Capacity
# Aza-Michael Addition
# Diffusion Media
# Two-Diode Model
# Phosphatidylethanol
# Cu0.5Co0.5Fe2O4
# Ni-Mn-Sn
# Precolumn Derivatization
# Low-Buckled
# TE - Terrestrial Ecotoxicity,
# Overlap Concentration
# CO Mole Fractions
# Parabolic Fitting
# Ga1-xZnx)(N1-xOx
# Gqd
# Poly(Ether-Ether-Ketone)
# TiO2-0
# 2-Au
# Mean Drag
# Sulfur Annealing
# PCA Loadings Plot
# Nonoxide
# Atg
# 3-Ethylrhodanine
# Socie
# AA2024-T3 Aluminium
# Adrenochrome
# CaNi5
# Dehydration of Alcohols
# Uranyl Hydroxide
# Plant Area Index
# Chemical Patterns
# Snow Density
# Anisotropic Parameter
# OH Mass Fractions
# Opening Polymerization
# CW-MFC
# Ion-Induced
# Pulmonary Toxicity
# Enzymatic Amplification
# XMn2O4
# Rayleigh Equation
# Two-Tailed T-Test
# Cs2AgInCl6
# 2,7-AQDS
# α-Pu2O3
# NOx Storage Efficiency
# Density Functional Reactivity Theory
# K°
# Calcium Activity
# Radiation Cross-Linking
# Amidogen
# Pull-Out Force
# Dimethyl Fumarate
# Cerulenin
# Hydrogen to Carbon Ratio
# Tension-Compression Yield Asymmetry
# Impedance Method
# Electroanalytical Methods
# LTQ
# Electrochemical States
# NC-Si:H Layer
# Safranin
# Wall Potentials
# IVP
# Impurity Spins
# Li+ Diffusion Distance
# Purification Efficiency
# Electron Emission Properties
# CS2-n
# Dibenzodioxocin
# Surface Physics
# Obidoxime
# Herington
# Plane Scan Analysis
# Gel-Like Behavior
# Microwave Attenuation
# Precipitation Technique
# 18 O2
# Bone Remodeling
# Kendrick Mass
# SOS
# Elliott
# As-Obtained Composite
# Lysophosphatidylcholines
# SEM Tomography
# Hydroxyl H
# Spectrums
# Xanthine Oxidase Activity
# Use-Wear Analysis
# Elliptic
# Tf2O=Trifluoromethanesulfonic Anhydride
# Ph2PCH2PPh2
# Photo-Current
# Pitzer Models
# Discharge Cycle Performance
# GIWAXS Patterns
# Fano Effect
# Trombe Wall
# Biological Inertness
# L-AA
# Ferro-Orbital
# mKdV Equation
# Vinyl Propionate
# Receiver Operating Characteristic (ROC) Curve
# GISAXS Patterns
# ΔTIP
# Intragastric Administration
# Ion Association Constants
# Thermal COP
# Nuclear Fuel Rod
# Tills
# Hartree-Fock Theory
# δ13C Composition
# Positive Ion ESI FT-ICR Mass
# Saccharification Rate
# H2SO4 HCl H2O
# Isothermal Two-Phase Equilibrium
# Hydrogen Release Kinetics
# Sodium Arsenate
# Coated Glassy
# Fission And
# Energy Function
# Bardeen
# Nanocactus
# Carbon Dioxide Clathrate Hydrates
# Cu 2p (D)
# Suberate
# Releasing Hormone
# Process Capability
# NADPH/NADP+ Ratio
# α-HH
# Dual-Scale
# Stiffness Constant
# Airborne Laser Scanner
# TiOCl2
# Vmain
# Vibrational Cooling
# C96H24
# Electronic Disorder
# Space Structures
# EF1
# Li-Ion Capacitor
# Ni-NTA
# Oil-Water
# Vitrinite Isoreflectance
# Apob
# SGLT1
# Accurate Mass Measurements
# Sapt2
# Pyridine-2-Carboxaldehyde
# PEG114-B-PBLG22
# SWRC
# PPEGMA
# Disquac
# N-Octadecanethiol
# High-Frequency Electron Paramagnetic Resonance
# Ag3D XPS
# BREE
# Dpl
# Slowly Relaxing Local Structure
# Mitochondrial ROS Production
# Human Visual System
# Trading Scheme
# Multiexponential Global Analysis
# High-Speed Particle Image Velocimetry
# Bubble Nucleation
# Vaccine Adjuvant
# 2,2'-Biimidazole
# Solute Release Kinetics
# NRTIs
# EHN
# Mechanomyography
# Alloy Chips
# Ru85Se15
# K0.5Bi0.5TiO3
# Sheath Edge
# Fiber-Based
# Boundary Layer Wind Tunnel
# Coagulation Kinetics
# Air Velocity Ua
# Conduction Velocity
# Inverse Relaxation Time
# Topiramate
# Photoelectron Density
# MeNHOMe·HCl
# Solver
# Hes
# Fourier Coefficients
# Water Wells
# Nonreciprocity
# Sr3Al2O5Cl2
# Protochlorophyllide
# Combustion Experiments
# β0
# Entropies of Transfer
# Direct Solar Radiation Pressure
# Herbicide Resistance
# YSWC
# Monitoring Charts
# Cerebellar Granule Cells
# Frenkel-Halsey-Hill
# IrxSnyRuzO2
# TiO2-I
# Chemical Weathering Rates
# 2-Errors
# Earth Building Tools
# Li
# x
# NiO2
# FEs
# DCT Treated
# Hydroxyl Group
# Patterned Deposition
# Flame-Retardancy
# J M (M)
# 3L
# Physics C: Solid State Physics
# Alpha/Beta Heat Treated
# 4C2H
# CJ Detonation Velocity
# Cubic Inverse Spinel
# SLJS
# Normalized Transmittance
# Ecological Engineering
# 23-8-N Nitronic Steel
# MgXO
# La(OTf)3
# Boiling Flow
# Abrasive Wear Performance
# Helium Ions
# - Mobility Two-Dimensional Electron Gas
# Pd-PEG
# GWA
# Non-Enzymatic Hydrogen Peroxide Sensor
# Steroid Profile
# V Tfl
# Heating Rod
# Intracerebral Hemorrhage
# MBJ+U
# Different T
# Amplitude Plot
# Harman
# Cielab
# Hollow Nanocapsules
# Supramolecular Templating
# THBA
# Shear Yielding
# PMMA-B
# AZO3
# NR3
# Fusion Power Reactor
# Ultraporous
# BPO4
# MCNP Code
# 4-Cyclohexyl-2-Butanone
# Spectropolarimeter
# PVP-K30
# Coarsening Mechanisms
# Channel Beam.
# Singular Behaviour
# SFDLBM
# Cuprac
# Herschel
# Receptor-Binding Domain
# AZXY9120
# Wind Power Integration
# Terrylene
# Electron Field Emitters
# Potentiodynamic Polarisation Studies
# Electrostatic Deposition
# Ph3CCl
# Flow Pattern Transition
# Injection Analysis
# Poly(m-Phenylenediamine)
# FePcCl16-NH2-SiO2
# Θ S
# Water-Soluble Fluorescent
# Illuminated J-V Curves
# ECA Pressed
# Bright State
# SiO2-GO
# Entropy of Dissolution
# (Al,Cr)2O3
# OH Fluorescence
# Thermodynamic Losses
# Climb Force F 2
# Computational Integral Imaging Reconstruction
# Open Circuit Stability
# Intermicellar Interactions
# Weibull Distribution Function
# K-Urea
# Solid State Nuclear Track Detectors
# NiCo OH
# PEO–PCL
# Zero Field-Cooled
# Titanium Disulfide
# Electronic Surface Properties
# LiNixCoyMnzO2
# Social Value
# Nopaline
# Conformational Landscape
# Co-SBA-15
# Electroconvection
# Alkyne Hydrogenation
# Critical Clearing Time
# Li-Ion Insertion
# Switching Response
# RY/B
# Badhwar
# Pb2+ Removal
# Sciatran
# Thermally Transferred Optically Stimulated Luminescence
# Conducting Channels
# Sodium Phosphate Glass
# Force-Distance Measurements
# Magnetization Jumps
# NnBu4]2[TeCl6
# NWs/TiO2
# NRDS
# Q-Axis
# Gd0.1Ce0.9O2
# ZnO(000)
# NifEN
# Radon Activity Concentration
# Demineralised
# STM-TEM
# Adsorptive Behaviour
# Thin Film Hydration Method
# C-H Oxidation
# Subsurface Reservoirs
# Computer Aided Diagnosis
# Ti-Rich
# Selective Catalytic Reduction of NOx with Ammonia
# Micro-Spheres
# Thermal Contact Conductance
# High Resolution S 2p
# Prenol
# Low-Temperature SOFCs
# HOR Voltammograms
# Rideal
# Formate Lyase
# Asphaltic
# Octyltrichlorosilane
# Twin Walls
# Scanning Reference Electrode Technique
# Cardiovasc
# PCD
# Magnetically Dead
# Esterification Of
# Frequency Parameter λ
# Calcium Treatment
# Bond Interactions
# Time-Dependent Photocurrent Response
# H3PO4 Treatment
# Ag AgCl
# Zn(1) N(3)
# Bosch Process
# 4-IBAP
# Co-Adsorption
# η P
# Constant Load Method
# CO Adsorption Behavior
# Weighted Least Square
# Selective Oxidation of Methane to Methanol
# Intensity Modulated Radiation Therapy
# Carbonyl O
# HERS
# Cold Isostatically Pressed
# 2-Hydroxypropyl Methacrylate
# Ipib
# Magnetic Field Sensitivity
# Bismuth Nickelate
# Pitch Angle Response
# ECAP-C
# Layer-by-Layer Self-Assembly Method
# Cauchy Model
# Structural Polytypes
# Oxygen PIII
# Vibrational Sample Magnetometer
# MPCF
# Oxygen Permeable Membranes
# Environmental Embrittlement
# Al-Ca
# Oxidatively Stable
# Crash Risk
# Ti-4733
# RDE Polarisation Curve
# Zone Center Phonons
# SIMPCA-Wc
# Atomic-Resolution Imaging
# Bhattacharyya
# Ferroelastic Phase Transition
# Argon Ion Milling
# Particle Mesh Ewald
# Mmr
# Two-Stage Gas Boriding
# F γ
# Camp Assay
# C+IrO2
# Harmony Memory
# Total Organic Content
# Bozzolo-Ferrante-Smith
# Afam
# ψ Min
# Specific Anammox Activity
# Manganese Silicide
# HVFA
# ε X
# Multimaterial Cell
# E1I1/E2I2
# Proton Disorder
# Excited-
# Cross-FRF
# Calibration Range
# Feed Efficiency
# Field Emission Gun Scanning Electron Microscope
# S-BDP
# Double-Hydrogen
# JCPDS-ICDD
# Turn-On Fluorescence Response
# 1M NaPF6
# NDR Characteristic
# LHT
# Tetrahexahedron
# Molar Enthalpies of Dissolution
# Anodic Charging Currents
# 3-PBA
# Non-Dendritic
# O-Xylene Isomerization
# Knee Arthroplasty
# Doped Partially Crystalline
# Hydrogen Storage Kinetics
# Visible Infrared Imaging Radiometer
# C6H5NH2
# CO2 Temperature-Programmed Desorption
# Cu/(Zn + Sn)
# Disinfectant
# Robust Controllers
# Horse Liver Alcohol Dehydrogenase
# Slip Resistance
# R-3
# Energy-Dense
# Activity Parameter
# Selective Oxidation of Propane to Acrylic Acid
# D2S
# Prigogine
# MCU
# 3-(4,5-Dimethyl-2-Thiazolyl)-2,5-Diphenyl-2H-Tetrazolium Bromide
# TMD-MR
# High-K Gate Dielectric
# HoAs
# P-Toluenesulfonic Acid Monohydrate
# Conductance Levels
# Field Burning
# TE Content
# Marine Structures
# Bosphorus
# Magainin 2
# Boron Trifluoride
# Raman Spectral
# Dehydroandrographolide
# TriIPB
# Aliphatic Hydrogen
# Chemical Patterning
# GaSe9
# NaFeAs
# Nitrofurantoin
# Melt Index
# Mwa
# EZPE
# STEM EDX Mapping
# Non-Hermitian
# 3-MH
# CZ-68
# H/Ceff
# I-W Curve
# IFEM
# Power Law Regressions
# Sulbactam
# Poly(Arylene Ether)s
# Precise Point Positioning
# C2/c
# DQWS
# Silks
# α-Glucose
# Microtwinning
# HTAC
# Microrheology
# Compressive Spectral Method
# Dynamic Compressive Strength
# Co–28Cr–6Mo
# N2 — N2
# Low Velocity
# Shear Response
# F(Rh)
# Fe2Mo
# Nanodimer
# Fault Tree
# PolyA(Styrene Sulfonate)
# Multiaxial Fatigue
# Sea States
# Sacrificial
# Cyclic and Differential Pulse Voltammetry
# Mn4N
# Escompte
# DNO
# Photovoltaic Field
# Spin-Polarized Fermi Surfaces
# Diepoxy
# Laser Surface-Engineered
# MADIX
# Polyvinylbutyral
# Chromatographic Analysis
# Toluic Acid
# Corrosion Barrier
# Spark Gap
# Melt Electrospun
# Stokes
# MA Performance
# Intracellular Distribution
# Co(4)
# Release Ratio
# Effective Dose
# Al2Cl7
# Membrane Fiber
# Anaerobic Granular
# Lattice QCD Calculation
# Selective Ion Monitoring
# MT-150A
# SiO2-CN
# Lt-Approach
# 2-Amino-1-Methyl-6-Phenylimidazo[4,5-b]pyridine
# CH2Cl2 Bu4NPF6
# Stain Etched
# Apatite-Like
# Monolayer Sheet
# Nomarski Optical Micrographs
# Slrr
# Alloy NRS
# Lattice Properties
# TTCA
# Delta-Processed
# Zeolite Bronsted Acid
# Wagner Equation
# Surface Analytical Methods
# Photoelectrochemical Water Splitting Performance
# Temperature Program Reduction
# -Chip Integration
# Exchange Bias Properties
# Plate Connections
# Backpropagation
# Toxb
# Tox
# TE Parameters
# L-MBE
# Speciation Calculations
# Tunable Properties
# Coordination Bond Lengths
# Non-Destructive Test
# HDFC9OH
# EtS
# International Thermonuclear Experimental Reactor
# AFM-SECM
# (ZnS)1−x
# LiClO4 (8:1)–Al2O3
# Leaching Ratio
# Serp
# Working Life
# BeH
# Pawley
# P 2 1
# RMS Residual Error
# ADSA-P
# Maritime
# Λair
# Cmes
# Acrylic Polyurethane
# Ethylcyclopentane
# Anion Binding Properties
# Roll-Bonded
# Rth
# Pipemidic Acid
# Chlorophyll Fluorescence Yield
# CO2 Selective Membranes
# Crystalline Fibers
# Mono-Like
# Slurry Infiltration
# Direct Methanol
# Co3O4-110
# Interfacially Polymerized
# Fe-Mt
# Unreinforced Alloy
# TRPS
# C(1)N(1)
# Si/Cr Ratio
# Mega
# PDMAAM
# Vibrational Predissociation
# Sheet Density
# Alkylperoxy
# 13C Shifts
# Continuous Wavelet Power Spectrum
# Cr(VI) Reduction Efficiency
# Dynamic FTIR
# Aluminium Titanate
# Grain-Refined
# 1.0M
# High - Pressure Mercury Intrusion
# Beer
# Acylpalladium
# Nanotechnological
# Ssn
# Hydrolytic Resolution
# Metabolic Activities
# Electrostatic Actuator
# Pb(Zr1-xTix)O3
# Sonoelectrolytic
# Fractional Shortening
# Advanced Heavy Water Reactor
# C2F3X
# Interfacial Electron Transfer Rate
# Corrosion Defects
# Diethylamino
# Proximity-Induced Superconductivity
# DNMT
# Shock Resistance
# Calbindin
# Crac
# Thermodynamic Features
# Tetrasulfide
# Heave Added Mass
# RGO-Au
# PV Properties
# Specific Polysaccharide
# Phenazine Methosulfate
# Anti-Atherogenic
# F-Testing
# Cyclic Durability
# TEMPO-Oxidized
# Mannich Bases
# Anti-Icing Applications
# CC-PCVxZ-SD
# Csns
# Predictive R 2
# Igma
# CO2−
# Selectivity to Isobutene
# Palaeocene
# CH3CHO+
# Metallic Superconductors
# SPCEs
# Mechanical Clinching
# Drill Wear
# Beet Sugar
# Rietveld Calculated
# Honeycomb Network
# Sensing H2O2
# β;
# RSK
# Prismatic Slip
# Vehicle Fuel
# Mg–4Zn
# HOAc-H2O
# ρ ↓
# Six-
# Methoxyacetonitrile
# Pearlitic Ferrite
# Solar Radiation Models
# Chloroethene
# Polymer Batteries
# CMV
# 3,7-Dimethyloctanol
# Planar Coupling Factor
# Redox - Activity
# Conformational Angles
# Logic Operations
# Fish Feed
# C(Mo2C)
# ωP
# Ri - MP2(Full)
# CoFe2-xGdxO4
# Shielding Parameters
# DNA-Ag
# CZTSe
# Mg(NH2)2-2LiH
# Periodic Anderson Model
# Sephacryl S-100
# Anisotropic Elasticity
# Sulfur Removal Capacity
# Thermally Etched Polished
# Drainage Rate
# Electrical Porcelain
# Probe Electrode
# Gas Transport Performance
# Isothermal Magnetization Measurements
# S/F Ratio
# P(r)/r
# Sonoelectrolysis
# Chloranilate
# PtSn4
# Koutecky-Levich Equation
# N,O-Bis(Trimethylsilyl)acetamide
# Hydrocarbon Traps
# True Stress Vs
# Isoacteoside
# M G
# PolyA(N-Isopropylacrylamide)
# Specific Weight Gain
# T Si
# Soil Stress
# Theaflavins
# Dichloride
# Alexa 594
# Photocurrent Density vs. Voltage
# Oxygen Transport Mechanism
# Colloidal Nanoplatelets
# CuSO4
# +0.1M H2SO4
# Retouched
# Supercritical Assisted Atomization
# P(NIPAM-co-PyAM-co-DAEAM)
# PdSe2
# [MTBE]0
# Aerodynamic Size
# Butyl Alcohol
# KgCO2
# S1/D
# Rans - Les
# CCK-8 Kit
# Vaporization Curves
# Leptin Resistance
# High Frequency Capacitance-Voltage
# Cellular DNA Content
# 2 Binding Energies
# Ferritic Oxide
# GSH-Px Activity
# Water Treatment Technology
# TiPd
# Chemical Transport Model
# 1-Norm
# Amperometric Detection of Glucose
# DG0
# Rotating Blade
# Statoil
# 11β-Hydroxysteroid Dehydrogenase
# Biosensing Properties
# Anhydride-Cured
# Micromirror
# Oxonine
# LSP-2
# Primary Ferrite
# Quantum Logic Gates
# Time-Lapse Microscopy
# 5-AVA
# Poly(NaAA Co AAm)
# Zero-Energy Landau Level
# C4H8O
# Honey-Comb
# Grain Boundary A
# Aqueous Synthesis
# Substrate, Pure
# Crystallization Transition
# Photoinitiated Raft Dispersion Polymerization
# HIPIB
# Aspen Plus(tm)
# Hexanedithiol
# AlAu4
# Stack Performance
# Cyclopentane Hydrogenolysis
# Multi Stage
# Thermoreflectance
# BCS-BEC Crossover
# TRFQ
# Guanosine 5'-Triphosphate
# TEFF
# Superconducting Electronics
# Piezoresistance
# Supramolecular Nanofibers
# Stannic Chloride
# Fullerides
# Ammonia Aqueous
# Binding - Energy
# Nanotube Sheets
# PRS
# Post-CMP
# BTME
# Mg4Al2
# Paramelaconite
# NixCo3 xO4
# Model Reference Adaptive Control
# Reflection High-Energy Positron Diffraction
# DCFDA Assay
# DP590
# Cytotoxic Potency
# Be(II)
# O Red, C Black
# Thermomagnetic Measurements
# ZIF-11
# CGH
# Me2O
# Li Ion Conducting
# Hydrogen Desorption Charge
# Dialkyl Disulfide
# C12Maltoside
# Unidirectionally Rolled
# Multi-Step
# Pipe Surface
# 1,2 Dimethoxyethane
# Doped/Codoped
# Skeletal Remains
# Iodixanol
# Mn Carbonate
# Electromagnetic Induction
# Atomic Absorption Spectrometer
# PPG725
# Purine Nucleoside Phosphorylase
# Ti2O9H10
# Swanepoel Method
# Three Dimensional Numerical Model
# PPh3CH3Br
# Naphthalocyanine
# Transconductance Generation Factor
# Lithium Vanadate
# Galvanostatic Discharge Profiles
# Solar Wind
# Microstructural Transformations
# TDMAT
# X-Component Velocity U
# Tangential Contact Force
# Piecewise Parabolic Method
# Thermal Radiation Parameter
# PCM Devices
# Resistivity Anisotropy
# DN285
# Multiway Principal Component Analysis
# Slug Test
# α-Mo2C(0001)
# TDPA–KCl
# Crystallite Morphology
# Aerodynamic Loads
# Gene Therapy Applications
# VIP-Plot
# Scanning Auger Electron Spectroscopy
# (0 0 0 2) Pole
# Lithium Cobalt Oxides
# Cl- Channels
# Penning
# Asymmetric Supercapacitor Devices
# Δκ s
# Hyperdoped
# Labile Carbon
# Occupancy Parameters
# NCPES
# Edge Boundaries
# Edge Moment Factor
# AC Magnetization
# Potentiodynamic Plots
# CO2e
# Mitochondrial Swelling
# Rapid Vibro-Milling
# Mocage
# Germacrene D
# Streamline Upwind Petrov-Galerkin
# Evaporative Crystallization
# Phospho-P53
# Sulfur Isotope Values
# Carbon Molar Fraction
# Oxide-Mixed Method
# Surface Gap
# Thermal Tests
# Friction-Transferred
# Specific Activity Distribution
# ITCs
# Δsθ
# Summation-By-Parts
# OMIM][BF4
# Constructability
# Closeness
# Intrinsic Factors
# 4-N,N-Dimethylaminopyridine
# V2O5-1
# One-Pot Solvothermal Route
# Cluster Deposition
# Classification Error
# Thermal Creep
# Ril
# Chemical Exergy
# Ti+22Al
# Tocatalytic Activity
# Rockwell Indentation
# Hci
# Cr2O3(0001)
# La2O2CN2
# Sm/Yb
# Vaporization Curve
# TPA Properties
# Lower Limb
# Derived
# Ru(4)
# Chemical Flexibility
# Fe3O4 NH2
# Spatial Magnetic Properties
# I-P Plots
# Cu75Hf20Dy05
# BMD
# Solidification Model
# Nanocubic
# Harmonic Oscillator Model Of
# Photogenerated Electron / Hole Pair
# Reforming of Hydrocarbons
# Poly(LLA-co-CL)
# S O L I D S V o l
# Nutrient Removal Efficiency
# Cpg Islands
# Fingerprint Texture
# S C T
# Lead Vacancies
# Ionic Clusters
# SET-LRP
# Oil and Gas Pipelines
# PFET
# 1,3-Pentadiene
# TEHP
# Lattice Anharmonicity
# I3Electrolyte
# Ebb Velocity
# Nsted Acid
# Spectrally Integrated PL
# Solution Blow Spinning
# Evaporation Technique
# Al NO3
# DICM
# 11b{1h}
# Cecal
# Mo–V Steel
# Derivative Spectra
# Low-Temperature Hydrothermal Method
# Absorption Spectrophotometry
# Photoactivated Localization Microscopy
# PDADMACl
# Sorption Experiments
# Thermal Buffer Tube
# Whole-Genome Bisulfite Sequencing
# CH2(CN)2
# –Cl
# Vhtrs
# Akaganeite
# Intergranular Layer
# SrIn2O4
# Hydrogen Absorption Isotherms
# PEI2LA
# Na D Line
# ω G
# Sensible Heat Storage
# Th/Yb Ratios
# FSCs
# Pparg
# XPS Mo 3d
# Texture-Etched
# Electricity Industry
# Propylcyclohexene
# Pt–BaO
# Charged Aerosol Detection
# Nb2O5*nH2O
# Load – Extension Response
# Aspen HYSYS(r)
# Polybutene-1
# Photocurrent Gain
# C12SH-SAMs
# Sers Chip
# Mechanically Induced Self-Propagating Reaction
# Exploration
# SG Behavior
# Hydrogen Molar Flow Rate
# Core-Shell Composites
# Series Coefficients
# Thermochemical Heat Storage
# Nanos-
# Extrusion Behavior
# Butane Isomerization
# Minimally Invasive Surgery
# Topological Orders
# Current Time Chronoamperometric
# Pseudocubic Eos
# Cross-Flow Heat Transfer
# Butler Model
# Content-Based Image Retrieval
# Si-P
# Bpy][CF3SO3
# Cod Removals
# Arabinoglucuronoxylan
# Cycling Experiments
# Biological Pump
# Ce4
# Brain Connectivity
# POPA
# Mvk
# NiC2O4·2H2O
# Steric Effects
# STEM-ADF
# FePc G
# High-Resolution Thermogravimetry
# MILP Model
# Saturated Water Content
# Interposer
# Trans-4-Tert-Butylcyclohexanol
# Calcite-Type
# Ultrasound - Targeted Microbubble Destruction
# Photochromic Performance
# Noise Ratio
# Precision Agriculture
# Methane Potentials
# Surface Isovalue
# Artificial Photosynthesis System
# Single Quadrupole Mass Spectrometer
# Fenpropathrin
# C4H5
# α C
# Impact Potentials
# TRZ
# Corrosion Cell
# Fluctuation Theorem
# Pavement Layers
# Semicoke
# Powder Injection Moulding
# Niclosamide
# Space Infrared Telescope
# NH3 Detection
# Non-Darcy Flow
# Superhydrophobic Character
# DG
# NH4Claq
# Tmean
# Stark Effect Measurements
# HDR
# Cox Regression Analysis
# YCH
# TAZ711
# Bis(2-Ethylhexyl)sulfosuccinate
# Fourier Transform Infrared Measurements
# DM−3 SO2
# Cartilage Defects
# TFEB
# Na2W4O13
# Oxovanadium(V)
# Oscillatory
# Dilational Rheology
# Soil Bulk Density
# [11C]CO2
# SO
# Tan(ψ)
# 2-D Code
# DGDG
# Fatigue Crack Growth Behaviour
# Hydrodynamic Theory
# Fe-X
# Momentum Constant
# Seismic Observations
# Standard Gibbs Free Energy
# Z-Scheme Photocatalytic System
# Novo
# Barium Vacancies
# Majorana Edge Modes
# Mc-Lr
# Ce0.8Ca0.2O1.8
# Semiconductor Characteristics
# Magnetic Torque
# Synchrotron Radiation X-Ray Diffraction
# Short Circuit Density
# Pd-Ga
# Humic - Like Substances
# Fe2O3(001)
# LOQ
# Bonferroni's Post-Test
# QC2-Br
# B Gs
# Neutron Capture
# TDCPP
# Time - Of - Flight Mass Spectroscopy
# Singular Value Decomposition Method
# H*
# Conversion-Type
# AA7075–H2O
# DEF2
# Surface Activated Bonding
# Breathability
# 800degc
# MN Sec
# FLN
# M–I) Transition
# Chiralpak AD-H
# Tunneling Resistance
# Energy-Related
# CAM-B3LYP
# Electron Dispersive X-Ray Analysis
# BHMTHF
# Fragile
# Electrocatalytic Test
# Polyaspartate
# Rster
# Topological Physics
# G:
# Fuel Synthesis
# Quadrupole Mass Filter
# DMSO2
# γ-Glycidoxypropyltrimethoxysilane
# S–N–K
# Tall
# Shortwave Radiation
# Seeded Hydrothermal Synthesis
# Rapid Liquid Phase Sintering
# DHBA
# Trihalide Perovskite
# Green Dnd-26
# NPs@ZnO
# Metamolecules
# Ferromagnetic-Paramagnetic
# C3N6H6
# Glycobiology
# Fuel Source
# Histogram of Oriented Gradients
# Ward Method
# GVS
# Electro-Fenton Treatment
# damage profiles
# Enzyme Replacement Therapy
# Doped Single
# CisPt
# Core-Shell Morphologies
# Green's Function Method
# I E Loops
# Composite Hollow Fiber Membranes
# CoC2O4·2H2O
# Failure Properties
# Hypoiodous Acid
# Dielectric Characterisation
# T-Beams
# Linear Parameter Varying
# 4-PZT
# TES Applications
# Rpvs
# Becke
# α-VOPO4
# - Producing
# Γ Y 0
# C2H2O4
# CP,M
# IATCS
# Hartmann
# Distortion Parameters
# Silica NP
# Permeability to Water
# Immobility
# 13C-13C
# IO
# Lithium Rechargeable Cells
# Awj
# MPPT Control
# Subway Tunnel
# Solid State ASC
# 4-MP
# Hierarchical Nanocomposites
# Pump Limiter
# Bankruptcy
# DCNPSVM
# SCHL
# Nitrogen Ion Implanted
# Gas Cooled Fast Reactor
# GRIM
# Dcpp
# Wind Industry
# Color Emission
# Sb-SnO2-NGNS
# Schmidt Net
# Differential Optical Absorption Spectroscopy
# Conductive Atomic Force Microscope
# Icy Satellites
# IamOH
# Marine Coatings
# Electronic Assemblies
# Anomalous X-Ray Scattering
# Secondary Ion Mass Spectrometer
# NH Stretching Modes
# Boron Removal Efficiency
# Qualitative Compositional Map
# Vuggy
# EM Field
# Slurry Erosion
# Personal Digital Assistants
# Dd
# Limiting Flux
# Bi 4f and S 2p
# Bayesian Maximum Entropy
# FSP-Made
# FAPbBr3 Perovskite
# Texture Feature
# Finite Element (FE) Modeling
# Social Responsibility
# Emergency Department
# NR Composites
# Fault Displacement
# Na4ZnW3O12
# Ion Transportation
# Lead Selenide (PbSe)
# Theyaxis
# Confocal Micro-Raman Spectroscopy
# MITO
# Single Sensor
# Ternary Nitride
# Bulk Nanobubbles
# Density of Localized States
# Silver Lines
# TDOS/PDOS
# CO Oxidation Mechanism
# V / NI
# Spectroscopy Ellipsometry
# Eutectic Grains
# Single Pulse Energy
# Diethylnitrosamine
# Open-Framework Structure
# HCube
# Silybin
# Axial Capacity
# Perylene Tetracarboxylic Diimide
# Fe1Fe2
# Transient Creep
# NO–H2–O2
# Cyclic Voltammetric Current Function χ(t),
# Fuel Cell Testing
# CDMA
# AEBSF
# Streamwise Turbulence Intensity Profiles
# Post-Welding
# Upconversion Nanophosphors
# 1-Aminocyclopropane-1-Carboxylic Acid
# Oxygen Desorption
# RGO-Mn3O4
# Capture System
# / ZN Molar Ratio
# MFRT
# Secco-Etched
# Thermophoretic Sampling
# Strain Graph
# Na-FER
# Colloids;
# Galvanic Effect
# Spectrally Selective
# COD Removal Performance
# Ion Storage Capacity
# Spin Coherence
# Molecular Orbital Coefficients
# O/U Ratio
# Lsomo
# Vhf
# Cp/T vs
# Thed
# Bulge Testing
# DIPI
# Isobutene Yield
# Susceptibility To
# Dusting
# Signal Amplifier
# Crystal Grain
# Quickbird
# Loss Temperature
# CD-Music Model
# Two Dimensional Simulations
# Random Forest Regression
# Aro
# Δ18O Vs
# Pulse Wave Velocity
# Phthalazinone
# Wire Gauze
# Iloprost
# Collector Junction
# Facile Solution Method
# Magneto-Optical Devices
# P31M
# C/S Ratio
# Interface Slip Length 2 Y ( Z )
# Sintering Shrinkage
# Neuromorphic
# FSSS
# Spray Printed
# Al 7075-T6
# Half-Filled
# Eigenvalue Spectrum
# Hodgkin
# Heat Conduction Mechanism
# Insulating Characteristics
# Dssc Photoanodes
# Energy Dissipation Characteristics
# ξ2
# I DS V GS
# Manganese-Oxo
# Bell's Inequality
# Carbon Utilization
# GL-C3N4
# Mono-Doping
# Spr Absorption Band
# Inventories
# Titanium Hydride (TiH2)
# Wave Reflection
# Low-Pressure Nitrogen Adsorption
# KPa CO
# NC Machining
# ATP Sensing
# LCCC
# Microsegregation Model
# TEM-EDS Elemental Mapping
# Anterior Chamber Depth
# Drop Shape Recovery Experiments
# FC Stack
# Singlet Potential Energy Surface
# BEEM
# 2DESs
# Water Vapor Density
# SG-AEMH
# Phenomenological Coefficients
# Z(0)
# Textile Fibres
# Synergi
# Me-β-CD
# Hydrogen-Passivated Silicon
# Capacitor Behavior
# Micromorphological
# Hatch
# Nitroimidazole
# Energy Storage Material
# Monocristaux
# Atomisation
# Threadlike Micelles
# K-Illite
# Adrenal
# Emission Property
# Phospho-C-Jun
# Poly(Sodium-p-Styrene Sulfonate)
# birth weight
# Cd Element
# Cast-Rolling
# GeMn
# Stirpat
# Peak Resolution
# Nonlinear Theory
# α-PVDF
# Magnetically Separated
# Biophysics
# Au Fe3O4
# First-Order Reaction Model
# Sustainable Energy Systems
# Carboxybenzyl
# DSC Modules
# ABC
# Ring Plane Inclinations
# PPGs
# Fsar
# BP-10
# Ultra-Thin Gate Oxides
# SPR Difference
# Obsessive-Compulsive Disorder
# Green Fibers
# 3-NN
# STLF
# Carbonation Degree
# Nicardipine
# Neurology
# Cavity Microelectrode
# Ultraviolet Photoluminescence
# Glass Formation Ability
# Co(Fe)
# MTCVD
# Fluctuation Function
# Hexadecanol
# Allende Meteorite
# 4-Ethylguaiacol
# Vaporliquid Equilibrium Properties
# Genetic Engineering
# Gibbs Free
# Silvaco
# FcOH
# 1S,3R-ACPD
# Sensitivity Spectra
# λh Model
# δ-VOPO4
# 2,4-Dichlorophenoxy Acetic Acid
# Fibrosus
# Prestructured
# Magnetic Orientation
# Streamlines ψ
# Spiro
# Non-Isothermal Model
# Fe2O3-2
# SiO2-KH570-PMMA
# Chitosan-Polypyrrole-SiO2
# MeX
# Propylene Glycol Monopropyl Ether
# PWE
# Amendment
# PHEA-EDA-FA
# Platelet-Reinforced
# LIPSS
# PEO200
# Testate
# 1H,1H-COSY
# Osteosynthesis
# Oxygen Reduction Polarization Curves
# Br Concentration
# Solar Technology
# ChCl Glycerol
# PVD Coatings
# Morphological Defects
# H A
# Fold Test
# Li-Titanate
# Electrochemical Polarization Methods
# Triplet State Energy
# Arc Plasma Method
# Tafel Slope Plots
# F-Test
# VB Valence Band
# Two-Dimensional Structure
# Infrared Radiation
# Ag-AgCl
# Global Maximum Power Point
# Turbulent Fluidized Bed
# Cu (OH)2
# Turbulent Premixed Flame
# Polythionine
# O2 Ratio
# As-Prepared 2D
# Ce0.8La0.2O2-δ
# Pneumatic Spray Pyrolysis
# M-Terphenyl
# P/Ti
# Reliability-Based
# ORed
# As-Deposited Mesoporous
# Air Pollution Index
# Polyetheramine
# AA1050
# Retorting
# Lnz
# O2in He
# Lenticular
# Dienestrol
# Nerve Guidance Conduits
# Triazophos
# Si-N-C
# Supercritical Water-Cooled Reactor
# Coating Capacitance
# 15N/14N
# Physics Performance
# Dry Ice Blasting
# CH4HF
# AC HAADF STEM
# LBL Multilayers
# PECD
# MgB4
# G-FET
# 0 / r
# Short-Chain Carboxylic Acids
# Bisulphate
# Non-Heme Iron
# PiN
# Sc2(WO4)3
# Methylmalonyl-CoA Mutase
# Imidazolidinone
# MeOH-D4
# Spartan
# MOPA
# Na26ClBz
# Solidi
# Allergen
# Platinum Content
# Nanoparticle Crystals
# Serum Bottles
# Stribeck Curve
# Linear Polarizer
# Electrical Potential Difference
# H2 / CO2 Permselectivity
# Pentan-2-one
# Timoshenko Beam Model
# Deposition–Precipitation (DP) Method
# BdG
# Near-β
# BiYO3
# B→C
# Maximum Hardness Principle
# Polystyrene-b-Poly(Ethylene Oxide)
# Vibrational Energy Relaxation
# Velocity Ratio
# Heats of CO2 Adsorption
# GWHP
# Porous Parameter
# White Light
# Fluorescence Microscopic Images
# Intensity-Modulated Photocurrent
# Zr-Mo
# 2,2,6,6-Tetramethyl-3,5-Heptanedionate
# Fourier Filtered Hrtem
# FullProf Software
# Structural Degradation
# EABF
# Relative Paleointensity
# Piezoelectric Energy Harvesting
# Fluidized Bed Pyrolysis
# Bistable Behavior
# Pluripotency Genes
# Ocean Energy
# Valence Electron Density
# Doughnut
# TOCatalyst
# Upqc
# 2,4-Dinitrophenyl
# Scratch Adhesion Test
# Cell Therapies
# Terrylenediimide
# HDAC Inhibitor
# P-Type Semiconducting Behavior
# NG/UFG
# Diphosphite
# Thermally Modified
# Taphonomic Analysis
# Phonon Scattering Mechanism
# Mnf
# Nanoscale Thin Films
# Brunauer – Emmett – Teller Analysis
# DDC
# Gexc
# Carbon-Carbon Bond - Forming Reactions
# PMHT-Br
# Poly(β-Hydroxybutyrate)
# Antiferromagnetic Semiconductor
# Nuclear Reactions
# Formaldehyde Cross-Linked
# Multidimensional
# MIA
# Buffer Matrix
# CoefficientsA,B
# Potential Measurement
# Radiative Intensity
# THC Emission
# Tured
# Selected Ion Recording
# CeH
# NiZn-Ferrite
# Sulfuric Acid Pretreated
# Wine
# Plastic Compressibility
# ρL/ρG
# Packets
# Small Molecule Activation
# V2O3(0001)
# 1 Norm
# C(15)
# π 3
# Rebound Number
# NH3-SCR of NOx
# Ysncs
# DMDSe
# Al-B
# Co-Combustion Characteristics
# Urethane Dimethacrylate
# Tool Wear Ratio
# UHV - CVD
# Aliv
# Subcritical Water
# Statistical Significance
# Nonanuclear
# M2C Carbide
# Numerical Efficiency
# Limiting Current Density IL
# Radioprotective Activity
# Fueled
# EBPIS
# I Ph
# Saxitoxin
# FTIR Spectroscopies
# J B
# Exciton Blocking Layer
# Stereotactic Body Radiotherapy
# Fine Particulate
# Revenue
# Product Lifecycle Management
# Beam Emittance
# MTT Staining
# Ru-Ru
# Watson's A-Reduced Hamiltonian
# Adhesive Pads
# Reduction Peak Current Density
# Bitumen Recovery
# End-Quenched
# PEOT
# Ni2(Cr,Mo)
# Engine Control Unit
# Transmission Line Resonator
# PbA
# Methane Hydrate Stability
# Nanobeans
# Canonical Analysis Of Principal Coordinates
# 1H Spin-Lattice Relaxation Rate
# MmM5
# S1/S0
# Multi-Criteria Analysis
# Hexaniobate
# Et3NHHCO3
# Electrospray Technique
# Phase - Corrected Fourier Transform
# Au(PS)
# Scheelite-Type
# Fenofibrate
# Thermocell
# Mechanical Metamaterial
# Urea Pyrolysis
# Ud,s=0.14
# Magnetic Data Storage
# excitation profiles
# Ni4O4
# Absorption Indices
# Dodecyltrimethyl Ammonium Bromide
# Cycle Time
# Heterogeneous Electrocatalysts
# Core/Shell QDs
# Dilational Viscoelasticity
# A I
# Medically
# Weno-Symoo-Rl
# Li2O-SiO2
# DMMT
# SA633
# Poms
# Oxygen Indices
# Thermal Denaturation Curves
# Aluminisation
# 17O Nuclear Magnetic Resonance
# 6 31 1+ G(d,p)
# Anharmonic Approximation
# Stripixel
# Cavity Shapes
# 1,4,5-Trisphosphate
# ECE
# ΔΞ
# Quasi-Hexagonal
# Granular Mixtures
# Plutonium Dioxide
# Bioleaching Efficiency
# Lcoh
# Accounting
# Gdc
# Antibacterials
# GF109203X
# Potassium Citrate
# Li+ Conductive
# Solar Energy Conversion Applications
# Green's Function Solution
# Heat-Tolerant
# Spin-Polarized Density Functional Theory Calculations
# ZnRh2O4
# Voltage Stress
# Lithium-Ion Pouch Cells
# ALDH
# Geochronologic
# Shell And
# Photochemical Reactivity
# NaInS2
# Aerobic Biodegradation
# Ellipsometric Parameters ψ
# Py][TF2N
# Ginkgolide B
# Perovskite-Related
# S T R A C T Cubic
# Proficiency Testing
# D Orif
# Surface Mass
# Input Current
# Deformation Processing
# I2D/IG Ratios
# Dols
# Perturbation Formulas
# Salt Rejection Performance
# Projector
# Absorption Rate of CO2
# W2
# Band Tail States
# Density Gradient Theory
# SAPO-34-H
# Dithiolane
# La 2- x Sr
# Compressive Peak Stresses
# Selective Chemical Etching
# Bioautography
# Effective Coefficients
# Palladium - Catalyzed Suzuki Coupling Reaction
# Ca2+-Permeable
# Geochemical Diagrams
# HgTe CQDs
# Ribbon-Shaped
# Fischer-Tropsch (
# Poly(Dimethylaminoethyl Methacrylate)
# Expert
# Topographic Characteristics
# Molybdenum V
# Dg/Dl
# P/A G F Co
# Asslsbs
# Analytical Tools
# Hmf Yield
# Superoxide Scavenging Activity
# BCPR
# SAFT-
# [0 1 0] Zone
# Capacity Cycle Number
# Kurtz Powder Method
# Nb/Th
# CNCCl3
# Dynamic Aeroelastic Response
# Drought Tolerance
# Benzaldehyde Oxidation
# Sulfisoxazole
# Clonogenic Survival Assay
# Microstructure Homogeneity
# Histological Image
# Ammonia Sensing Properties
# τ^
# Fluorescence Derivatization
# H Stretching Frequency
# Aminoamide
# G5
# Emulsion Gels
# Gasification Activity
# RE-Ba-Cu-O
# Premixed Combustion
# Load Compression Curves
# Microscale Thermophoresis
# Antiferromagnetique
# Image Furnace
# 1,4-NADH
# Reactive High Power Impulse Magnetron Sputtering
# Bioinformatics
# Sherwood
# 2D-VRH
# Pre-Patterning
# Serum Glucose
# 2D Clusters
# Silver Oxalate
# Pac
# Tvoc
# Automotive Battery
# DDSC
# Characteristic Remanent Magnetization
# AgCl,KClsat
# SAW Device
# Efflux Transporters
# 3,5-Dicaffeoylquinic Acid
# Cold Pilgering
# Monothioarsenate
# Si Isotope
# C-Cu2O
# Lipophobic
# PCM-B3LYP
# RBulk
# ACP
# Plasma Decomposition
# Heterojunction Perovskite Solar Cells
# BRF
# HNCO Mixing Ratio
# Damping Model
# Ru(NH3)6
# BrCH2CO2H
# Deep Aquifers
# Al2O3-MgO
# Deuterated Methane
# UV Visible Transmittance
# Deproteinization
# Permittivity Dielectric
# Artery Disease
# Ohmic Contact Resistance
# TRPL Decay Transient
# C@MnO2
# Quorum Sensing
# CO Methanation Activity
# HER Catalysts
# 2-GCE
# Tetramethylguanidine
# Dox Loading Efficiency
# Resonance Raman Excitation
# Industrial Wastewater Treatment
# CO-Oxidation
# Nano-Sized Spherical
# Ca 2p3
# Non-Newtonian Viscosity
# BN-MoS2
# Self-Consolidating
# Hyperfine Splitting Constants
# Biomedical Alloys
# Lattice Parametersa
# UCN
# NH4NO2
# Melamine Cyanurate
# Grey Wolf Optimization
# Virion
# D19S433
# Floater
# Standard Heats of Formation
# CeO2 Sm2O3
# Frequency Parameter F
# Suppression Subtractive Hybridization
# STEM ABF
# WST Assay
# CH2COOH
# Normalized Kinetic Traces
# Gas Plant
# Swamp
# CA125
# OH-BDE
# Interaction Properties
# Hoop Strain
# C2F
# ROS Activity
# OT - CEC
# LuBO3
# Peroxidase Like Activity
# Corneal Transplantation
# Aviation Industry
# SI-GaAs
# Mass Absorption Efficiency
# Alkane Selectivity
# Early
# Tilted
# Colonoscopy
# Isothermal Differential Scanning Calorimetry
# Δ-HCH
# ADMP-MD Simulations
# Time-Resolved Images
# Differential Capacitance Curve
# Linear Birefringence
# Room
# Absolute Deviation
# Dilatometric Tests
# S-PAC
# Carbohydrazide
# Ristocetin
# Glass Rods
# Accretion
# Thermal Engineering
# Ce(NH4)2(NO3)6
# THDBT
# Rotational Echo Adiabatic Passage Double Resonance
# Three - Photon Absorption
# Glucose Selectivity
# Photoreduction of Cr(VI)
# Lutein Content
# Ball Mills
# 3D DIC
# SC - SOFC
# Si-O-Si Angle
# Potentiostatically Electrodeposited
# ATEM
# NaH2PO4 2H2O
# BiFeO3 Perovskite
# Iopromide
# Rotating Bending Fatigue Tests
# Dispersion Mechanism
# Organic Batteries
# Biotechnologies
# Saturated CO Adlayer
# Inkt
# EMIM][OcSO4
# Metatexite
# Lf - NMR
# Interatomic Bond Lengths
# N-O Bond Lengths
# ADMP
# electromagnetic forming
# MLCT Excited State
# NH2 SiO2
# Melting Pressure
# 1,4-Bis(1,2,4-Triazol-1-yl)butane
# MsCl=Methanesulfonyl Chloride
# Soft Electronics
# 3d-(n)gf
# SPS;
# Transparent Devices
# dL
# EHSF-N
# Panoramic SEM
# Compressive Fracture Surface
# Li-Ion Half-Cell
# Helical Gears
# Electron-Transparent
# TSCS
# Uranium Silicide
# Lithium Density
# Magneto-Hydrodynamic
# d-Amphetamine
# θO
# Microbicide
# GNSS Service
# AMS-02
# Sb(NO3)3
# Hfin
# LSTM
# Formate Production Rate
# PMN
# Hydrophilic Nature
# PC3
# Chitin
# Gas Hydrate Program Expedition
# Mn 2p and O 1s
# Sr3Ir2O7
# Charge Neutrality Level
# SAFT+Cubic
# Organohalide Perovskite
# Topologically Protected Edge States
# Columnar Films
# Tanψ
# WDS X-Ray Maps
# Filler Particles
# Co(5)
# PEG-An
# PHIC
# Taste Receptor
# Distribution Static Compensator
# Diencephalon
# PdCl2(DPPF)2
# T1 Contrast Agent
# Electrical Transport Property
# Bipolar Junction Transistor
# Spicam
# Current-Sensing Atomic Force Microscopy
# Chronopotentiometric Durability Test
# Perpendicularly Magnetized
# Poly(9,9-Di-n-Octylfluorenyl-2,7-Diyl)
# Ultimate Load Capacity
# Racemic Lactide
# Shock Compaction
# Dwarf Planet
# 2-Bromopyridine
# N - Doping Level
# Fast SCR
# Thermal Catalysis
# Bi-Lamellar
# PFAES
# Turning Rate
# Release Capacity
# Pyoverdine
# Ionotropic Gelation Method
# Related Defects
# Cetilistat
# Rutile;
# Extraction PH Isotherms
# Forced Vibration Characteristics
# Fe 2P
# Spin Ladder
# Monocalcium Phosphate Monohydrate
# Bilirubin Level
# ν R
# Solid Freeform Fabrication
# Flip Chip Technology
# Low-Energy Electronic Structure
# Dubinin-Radushkevich Equation
# Colburn Factor J
# Surface Charge Transfer
# Solution Absorption Spectra
# Optical Rectification
# LiBH4·NH3
# Phospho-FAK
# SFB
# Silicon(II)
# Microbial Resistance
# Tetrathiafulvalene-Tetracyanoquinodimethane
# 2-RDM
# Pulsed EPR Spectroscopy
# Column Breakthrough Curves
# Lithic Clasts
# Bi(001)
# Animal Feeding Operations
# Deep Western Boundary Current
# Uniaxial Deformation
# Transarterial Chemoembolization
# N Concentrations
# Electron Cloud Distribution
# H Ex
# Hydrogen-Induced
# Metal Cathode
# Tube Inversion
# Hierarchical Superstructures
# Cob(II)alamin
# Amberlite LA-2
# Phenocryst Compositions
# Ag(4)
# Hückel Model
# Lamellar Structured
# PIPS
# Anaerobic Granular Sludge
# G3x-K
# M − M Eq ) / M Eq
# Desorption Studies
# Microfluidic Spinning
# Hydronium Ion
# Zinc Citrate
# nc-Si:H Thin Films
# 4ZrO2
# PEDFM
# PCNN
# Ag2CrO4 NR
# Cracking Mode
# Redox Activities
# Pharmacological Effects
# SO2 Flux
# Nuclear Overhauser Enhancement Spectroscopy
# Superconducting Vortices
# Atmospheric Dynamics
# CO2RR Activity
# (FA) Ferulate
# AAc2.6–Fe
# Mo–9Si–8B
# Ideality
# B4C/6061Al NAC
# C(5) C(6)
# Alteration Kinetics
# Pyrolytic Behavior
# Isobaric Vaporaliquid
# Osteolytic
# O-Ti-N
# Fan Blade
# RFD
# 2MR
# ζ a
# Surface Transition
# Cell Permeable
# B S T R A C T Eu3th
# (+)-CSA
# Loss vs
# SiO2 SH
# Loratadine
# Highest Occupied Crystal Orbital
# Nanocrystalline Matrix
# Horizontal Lifting Method
# POTS
# Metal Phosphonate
# Reti Energies
# Brain Capillary Endothelial Cells
# Formation Dynamics
# Calcium-Sensing Receptor
# GENECP
# Ferrogels
# Q 10
# CO2 Capture Behavior
# Charged Impurity Scattering
# Colloidal Crystal Template Method
# Sum of Ranking Differences
# Na2O/K2O Ratios
# Pollution Reduction
# PSC Method
# L-Xylulose
# Stern Model
# Closed Loop Pulsating Heat Pipe
# Frictional Entropy Generation
# Normalized Fluorescence Emission
# WGS,
# Spectroelectrochemical Characterization
# Absolute Principal Component Scores
# Cholangiocarcinoma
# Energy Density)
# Lc Ordering
# Hover
# Ni Mo
# Perot
# CL Image
# CO Molar Fraction
# Dust Loading
# Warm Pressing
# hydrolyzability
# Ilim
# Macroscopic CTE;
# Yolk Shell NPS
# Murnaghan Equation of State
# Anti-Doping
# Kurtz and Perry Powder Technique
# Microwave Roasting
# Thermal Vacuum Deposition
# χcc
# Indentation Response
# Acid Mine
# G-A
# Jahn-Teller
# Goblet
# Fatigue Peak Stress
# CTBS
# Coulomb Model
# σ Xy S
# S 2p, C
# Pt–ZrO2
# ScCl3
# Colon Length
# Electron Density,2
# Zn(AC)2
# Nanopore Electrode
# Metacarpals
# Ponceau Staining
# Cd(3)
# Multilayer Perceptron Neural Network
# Solvent Mixing
# CO Dissociation
# Gas Adsorption Isotherm
# Indicator Electrodes
# Non-Exponential Decay Curves
# Thermochromic Property
# EA-IRMS
# Benzenium
# Zn(Tb)S
# Anelastic
# DNA Mtase Activity
# EFP1/DFT Water
# HTSMA
# Coefficient of Heat Transfer
# ZnTiF6·6H2O
# Lithium Carbide
# Trifluoromethanesulfonic Anhydride
# Electromechanical Resonators
# 6-311+G(2DF)
# DACF
# Surface Incident Solar Radiation
# Exciton Model
# Analyte Stability
# Rhamnogalacturonan I
# β-La2Mo2O9
# Protein Solubility
# TOFF
# Methanol Activity
# Metabolic Dysfunction
# CAPP
# SRYL Model
# Marine Spatial Planning
# Silica MCM-41
# β-C2S
# PRRS
# PNNA
# Regulatory Responses
# δ60/58Ni
# Indirect Tensile Test
# Protective Character
# Ethanol Adsorption Isotherms
# Fossil Depletion
# Unoccupied Electronic States
# GPS VTEC
# Thin Fi
# Thermal Durability
# Pseudo-Landau
# Retting
# Proeutectic
# Ru–B
# Treatment Capacity
# Combustion Route
# Strength Performance
# N-Alkane Distributions
# Methanol Crossover Rate
# MMC-C
# Ruthenium Carbene
# Chloride Sensors
# Cardiac Myocytes
# TPA+
# Delamination Factor
# DETA-NO
# Smirnovavictorov Model38(Dashed)
# NAVCAM
# Cobalt Nitrate Hexahydrate
# Ferric Oxyhydroxides
# U¯
# SSMBE
# Rod - Coil
# Rock Mass Properties
# K h/K d
# Near Infrared Photoluminescence
# RTPL
# Liquid Water Distribution
# N-(3-Dimethylaminopropyl)-N-Ethylcarbodiimide Hydrochloride
# COD/TN
# Anode Channel
# Situ
# ω 1 / ω 2
# Opening Stress Distribution
# Gcmt
# Combustion Devices
# Compression Experiments
# Sulfur Cells
# Picts
# / Co Ratios
# AFM Force Distance
# MAPbI3thin
# Dorzolamide
# Granular Flows
# Amylolysis
# Bismuth Silicate
# X H 2 O
# Liquid – Liquid Phase Diagram
# HRCT
# Photocatalytic Function
# High Voltage Lithium Ion Batteries
# Irradiation Response
# P-ZnSe
# Nafion-H
# NdVO4
# Peritoneal Dialysis
# True Stress Exponent
# Au44(TBBT)28
# Actuated Strain
# Kinase B
# Corona Discharge Treatment
# Antihypertensive Activity
# CCSD(T) / Aug-CC-PVDZ
# Steryl Esters
# Aspirin Resistance
# Control Volume Approach
# Sn Perovskite
# API Fluid Loss
# Flame-Heated
# C-
# Thermal Management Systems
# Methylome
# Fire History
# Krf Excimer Laser Irradiation
# Selling Price
# mB
# Higuchi
# Wrinkling Wavelength
# Conductive Property
# Single-Cell RNA Sequencing
# Zero-Point Vibration Energies
# Vitro Bioassay
# DPSK
# Steel Mill
# Night Vision
# Proppant
# Atomic Efficiency
# Oz
# Bright Field Transmission Electron Micrograph
# Stability Indices
# 4-Sulfophenyl
# Wheel Life
# Deuterated Acetone
# Pitchfork Bifurcations
# Speed of Light
# Iron-57
# Ru (NH3)63+
# [C4mim]Br
# WGAE
# As-Oxidized
# SmCoO3 Perovskite
# As-Synthesized Flower-Like
# Photo-Excited
# Electrolyte/Cathode
# N×Out(L)
# Polycarboxylate Ether
# Densityg
# Natural Element Method
# MP2(Full) / 6-31G(D)
# α-Lactose Monohydrate
# Diffractometric
# Grid Electrification
# BrONO2
# T1 Contrast
# Halpin-
# 2-Ethyl-1-Hexanol
# Liquid Crystalline Mesophases
# Ru1 N3
# Cox-Merz Rule
# Bromochloroacetic Acid
# P-Contact
# Nitrogen Adsorption And Desorption Isotherms
# Copper(II) Acetylacetonate
# Ni-Graphene
# Elemental Properties
# Inac
# Mode Control
# QNM
# Temperature-Programmed Desorption of Pyridine
# Pd+
# P-Methoxybenzyl Chloride
# Gelling Time
# Punching Shear Strength
# Open Tubular
# Power Train
# Core-Shell Nanogels
# Wigner-Ville Distribution
# Diffuse X-Ray Scattering
# Y-ZrO2
# HDDA
# Dipolar Shifts
# Half-Cell Tests
# Photoprotective
# Biomasses
# Beacon
# Zn3In2S6
# Inelastic Spectra
# 3,5-Di-Tert-Butylquinone
# Antioxidant Profile
# Static Bending
# Tmf Life
# Affective
# 4,4'-Dicarboxy-2,2'-Bipyridine
# SBE-β-CD
# Quantum Design Physical Property Measurement System
# 3,3-Dimethylallyl Bromide
# Iron Alkoxide
# Solid Model
# Van Der Waals Volumes
# FAHS
# Calcium Oxalate Trihydrate
# Mo(Si1 xAlx)2
# Poikilotopic
# Hybrid Optimization Model
# Facing
# Epibatidine
# NC Size
# Al(V)
# Visual Guides
# Vibrational Spectral Analysis
# 4-Nitrobenzenethiol
# Hydrotrichlorosilane
# Na(3)
# THF MeOH
# Dissolved Silica Concentration
# Sensitivity Performance
# Vmep
# Pharmaceutical Properties
# Poly(9,9-Dioctylfluorene-Co-Benzothiadiazole)
# Kfs-K-Feldspar
# XPS O1s
# LiCrTiO4
# P-Type Charge Carriers
# O2 Fuel Cell
# Transverse Displacement Time History
# Ti(I)
# HPSO-
# Isochronally Aged
# Load Ratio
# Gravity Changes
# S-SiO2
# Composite-Like
# Microglial Cells
# Dissolved Hydrogen Concentration
# Dibromide
# Taxonomic Composition
# 56Fe
# Collision Cascades
# Lithium - Sulfur Cell
# PEO-GO
# Crystal Boule.
# C(31)
# Field-Induced Relaxation Times
# Spin-Valves
# Laser-Induced Heating
# Recyclable Catalysts
# PNK
# Electro-Catalytic Oxidation
# FeAg
# Flow Function
# Co-Substitution
# (1 1 0) Plane
# ISICS
# Sulfur Oxide
# Chua
# Charge Qubits
# Of-Life Vehicles
# Sinus Rhythm
# Co3O4-3
# Fe3O4 COOH
# HBF
# N-Acetylmannosamine
# Beryllia
# NG-Nitro-L-Arginine Methyl Ester
# Incompressible Navier-Stokes Equations
# Activity Curves
# DXS7132
# Structural Polymorphism
# Dendrite Arm
# Lignocellulosic Ethanol
# Mercury Flux
# MV2+
# Photoelectrochemical Reduction of CO2
# Two-Band Superconductor
# Nanosolder Particles
# NW/Graphene
# H Plasma
# Jet Milling
# PLA-g-MA
# Solution-Based Synthesis
# Dielectric Polarization
# Vehicle Dynamics
# WC O2
# Co SAs
# Micro-Flotation Tests
# Hydrogen Rate
# CeO2-20
# I P Characteristics
# Frontier Molecular Orbital Analysis
# BN - Page
# DP600 Steel
# Surface Spectroscopic
# SR/BA Ratio
# Ginzburg-Landau Equation
# Mo-Si
# SRAM
# EBBA
# Spatial and Temporal Adaptive Reflectance Fusion Model
# Stellite 21
# Chamber Slides
# Hypocrellin B
# Inblm
# Epimedin C
# MMDEA
# Equilibrium Lattice Constant
# CO Transition
# Ethyl Mercaptan
# Magnetic Defects
# Coal-B
# Biological Analysis
# Apparent Molar Volume Vof
# Fourier Transform Of
# Spin- and Angle-Resolved Photoemission Spectroscopy
# CO2Ratio
# A2B7
# EOR Applications
# Symmetry Analysis
# Antioxidant Content
# Synergistic
# Ar–H2
# GB179
# Imine-Na+-MMT
# Reactive HIPIMS
# Zero Field 57Fe Mossbauer
# Moisture Sensitivity
# Laxs Radial Distribution Curves
# Kibble
# S R
# LHTS
# Gas Transfer
# EGOPT
# σ 32 ∞
# Nitrogen Sorption Curves
# La(Mg0.5Sn0.5)O3
# CBMA
# Electrical Capillary Number,E
# Single-Phase Heat Transfer
# Impurity Potential
# Singlet Oxygen Emission
# Sabet
# Soil Hydraulic Parameters
# μ-XRD
# Anodically Formed
# Cation Mobility
# Polyphosphoester
# Static Friction Force
# RABS
# Direct Polycondensation
# Flat Heat Pipe
# FT-IR Spectrometry
# Kromasil
# K 0 Vs
# MIL-68
# Diketene
# Chemometric Tools
# Tungsten(VI) Oxide
# Flutter
# Christiansen
# 1,4-PDO
# ClCH2COOH
# Σ-Bonding
# AgNO2
# Electromigration Reliability
# Crystallite Orientations
# CD1
# Cu(In1-xGax)Se2
# Optimal Reactive Power Dispatch
# Rate Theory Model
# Lissamine
# Filtered-X Least Mean Square
# Well-To-Wheels
# Dopaquinone
# Co–W–B
# ZIF-9
# Relaxation Delay
# Chemical Fractionation
# ZK60 Magnesium
# Dynamic Motion
# Crossed Molecular Beam
# n-Butylammonium
# Hardness Ratio
# W-ZnO
# Blood Cholesterol
# μ(Mokα)
# Rotary Draw Bending
# PCR Analysis
# Tensile Fracture Mode
# Belief
# Saft + Cubic Model
# Magnetic Easy
# Matrix Films
# Supercritical Antisolvent Process
# Iron(III) Porphyrin
# F3CCO2H
# 3D CFD Simulations
# Ether Lipid
# Engineering Demand Parameters
# EHP
# Particle Anisotropy
# B-PVDF
# Luminescence Branching Ratios
# Physical Chemical
# Co3O4-100
# TiO2-Cu
# ORTEP - III
# Constant Phase Angle Element
# Aid
# Cavity Flow
# MEKC
# Sequence Lengths
# Wear Experiments
# NAB(4.5)
# LZn(SCN)2
# Critical Pitting Temperature
# Solution-Phase Method
# Static Stability
# Kondo Correlations
# Phosphated
# Threshold Voltage Model
# TLR
# Landfill Leachate Treatment
# Dichlorocarbene
# Inhibition Effect
# W Oxide
# LF Refining
# Ultrasonic Fatigue Testing
# Agg
# N2O Catalytic Decomposition
# Proportional Limit Stress
# BDDP
# Isotropically Scattering
# Diffusional
# R on,sp
# Oligo(Ethylene Oxide)
# HQVs
# BG57
# Wagner Effect
# Cu-MoO3
# 5,5'-Dimethyl-2,2'-Bipyridine
# Proteasome Inhibitor
# 1,4-Diiodobenzene
# 6.9MPa
# Mechanical Weathering
# Cracking Load
# Field-Amplified Sample Stacking
# Anodic Potentiodynamic Polarization
# Ge S
# Arzibs
# Potassium Efflux
# 22MnB5 Steel
# 4′-6-Diamidino-2-Phenylindole
# N-Acetyl-N-Nitrosotryptophan
# Methanation Rate
# Densification Curves
# O2fuel
# Faceted Crystals
# Wave Function Theory
# SonoVue
# Hardener
# Nondiamond
# Coefficient Matrices
# Microstructure Defects
# Permeability-Selectivity
# Non-Graphitizable
# Kurtz and Perry
# Z-Average Hydrodynamic Diameter
# Crushed Rock
# Nebulizer
# GEANT
# Displacement Reaction
# Solid - State Bonding
# Cpcms
# Functionally Graded Magneto-Electro-Elastic
# Rechargeable Battery Technologies
# Liquid-Phase Selective Oxidation
# PV3
# DNA-Au
# AuBP1C-MAM
# Borehole Thermal Resistance
# Homo-Lumo Energies
# Solar Energy Technologies
# Momentum Densities
# I02
# Schlitzer
# High Resolution S 2P XPS
# Fprop
# PTP Inhibitors
# Mineralization Kinetics
# Apatite-Inducing Ability
# Diazaborinone
# [Fe(Phen)3]2+
# Bioinformatics Analysis
# Clopyralid
# NiCoZn
# Alkaline Fusion
# Railway Embankment
# Creep Models
# Small-Scale Parameter
# BMGCS
# Crack Classification
# 4-NO2
# i3-Reduction
# Charge Inversion
# Antifreeze Activity
# Electrochemical Advanced Oxidation
# Propene Formation Rate
# Drug-Like Properties
# 152
# Benzylidene Malononitrile
# ATI
# F14C
# Bends
# Xn
# Jo2
# SiC-Nitride
# Cu2−xSe
# Tert-Butyl Methyl Ether
# Lithium Superionic Conductor
# α-ZOL
# Reverse Osmosis Desalination
# Microcryst
# Constituent
# Perovskite CsPbX3
# Weather Research and Forecasting Model
# V SR
# Leucrose
# S-MgO
# Lewis Acid - Base Properties
# Machining Operations
# Number of Hydrogen Bonds
# Interconnecting Layer
# Selectivity of CH4
# Keratins
# Strain Gradient Elasticity Theory
# Reduction of Dioxygen
# Huckel
# Bone Mineral
# Sedov
# TGG
# Drug Loading Capability
# Parton Distribution Function
# High-Energy LIBS
# Nanolevel
# Pd-Al2O3
# A Grains
# Poly(AMPS)
# Acid Recovery
# Post-Weld Heat Treated
# C-ZSM-5
# CAR
# PBDTTTPD
# N(1) C(1) S(1)
# Stereostructure
# Hydrolytic Degradation Rate
# New
# Dilatometric Analysis
# Aerobic Alcohol
# NAD(P)
# Urethane Acrylate
# Ethyl Caproate
# WGS:
# Ti 2p, (C) O 1s, (D) C
# LC3-II
# Echelle Spectrometer
# Of Adhesion
# Tetrachloroethane-1,2-D
# Sphingomyelins
# BIFTOOL
# H(2S)
# Wave Based Method
# Diamondene
# Porous Skeleton
# Pt-L
# Oxygen Deficiency δ
# PNVCL
# Metal-To-Ligand-Charge-Transfer
# Hexafluoroisopropylidene
# N-TBA
# Tgδ
# Galantamine
# X-Ray Photoelectron Emission Spectroscopy
# Dry Mixing
# Ofa
# LED Package
# G-II
# Ultraviolet Absorption
# LVM
# Wemple - Didomenico Model
# FFT Filtered Image
# Random Forest Model
# Thermal Ellipsoids POV Ray
# Fluid-Phase Equilibria
# Non-Linear Behavior
# Alloy Nanoparticle Films
# Ag(3.8)
# Macroreticular
# PFS80-b-PDMS960
# Rab
# Optical Ceramics
# Defect Center
# Strength Anisotropy
# Olanzapine
# HFSLM
# Ecosim
# Potassium Thioacetate
# Width Parameter σ
# Vegetation Phenology
# Hydrothermal Synthesis Route
# MMIC
# Interdiffusivity
# Ferromagnetic Quantum Critical Point
# Elastase
# Mg51Zn20
# Cell Capture
# Lowest Unoccupied Molecular Orbital Energy
# Multiple Criteria Decision Analysis
# Co Blue
# CF3CFCl2
# H 2 Production
# Oligomerization of Ethylene
# Mean Molal Activity Coefficients
# HBNH
# Tsat
# Ultrasound-Treated
# Protein Composition
# Music Model
# Huff
# Vicinal Cut
# VFB Applications
# FONs
# 298.15
# Separate Hydrolysis And Fermentation
# Pumping Losses
# Tablet Surface
# Reed
# Uncoated Foam
# Almen
# 87Sr / 86Sr(I)
# Plasmonic Sensing
# Joint Behaviour
# Compocasting
# Mass Conservation
# UC Phosphors
# N-I-P PSCS
# 8-Prenylnaringenin
# Pauli Paramagnetic
# Anticarcinogenic
# CaF2)(100−x
# Annular Dark Field Image
# Detection Threshold
# Tetranitromethane
# Qshe
# U–Pb Geochronology
# Tsallis
# Croconate
# Autoclave Treatment
# Specific Adsorption Capacity
# Vacuum Co-Evaporation
# Nebulized Spray Pyrolysis
# CA:SI Ratio
# 2D Raman Mapping
# Opposed-Jet
# γ-Radiolysis
# Polysynthetically Twinned
# Thermally Affected
# Autoclaved Aerated
# Combustion Flames
# Velo
# Rxy
# BMMCs
# Y(4NO2Cin)3
# Chiral Condensate
# 29Si Magic-Angle Spinning (MAS) NMR
# Ag|AgCl|1
# Wind Power Generators
# Loss G '' Moduli
# CSP Technology
# Ash Rejection
# Burial Diagenesis
# Split Neo-Hookean Model
# Bright Filed Tem
# Charge Behavior
# Bouligand
# Metalasupport
# Greenhouse Emissions
# RbClO4
# Photocatalytic Reforming of Methanol
# Settling Characteristics
# Titanol
# 1H,1H,2H,2H-Perfluorodecyltrichlorosilane
# CH4 Oxidation Activity
# GlcUA
# 2-Ethynylpyridine
# RR120
# Temperature Programmed Reduction of Hydrogen
# DEFCs
# Active Chlorine Concentration
# Nanosecond Laser Ablation
# Geotechnical Parameters
# Plasma Concentration-Time Profiles
# DC Polarization Curve
# Atherosclerotic Lesions
# Meso-HA
# Half-Time of Crystallization
# Lanl2dz-Optimized
# Whole Body Vibration
# Transverse Domain Walls
# APTES-GO
# Raman-
# Frontier Molecular Orbital Density Distribution
# Electronic Nematicity
# Shore
# Drug Retention
# CENDL
# Area Swelling
# FIBS
# Ta-Si-N
# (R)-2-Butanol
# Nisoldipine
# Sugar Conversion
# Centre For Medium
# Load – Strain Dependence
# PRSV2-WS-UNIQUAC Thermodynamic Model
# E/A Ratio
# Binder Jetted
# Long-Term Plasticity
# Mosquito
# Na2MnPO4F
# LDOSS108
# Bi0.9Pr0.1Fe0.9Ti0.1O3
# Orbital Amplitudes
# PEGDM
# GT-MHR
# Lithium Ion (Li-Ion) Batteries
# NHPA
# MANOVA
# Box-and-Whisker Plots
# Hydrogen Desorption Kinetic Curves
# Pachysolen
# PTMSPMA
# DAPI Nuclear Staining
# CRO
# Electronic Charge Concentration
# Dissimilar Alloys
# Amplex Red Assay
# XML
# InOx
# Cu Distances
# Viscous Heating
# 2-Heptanone
# Heart Function
# Forest Canopy
# Cation Channels
# Oxidative Capacity
# Pt–Cr
# Condensation Domain
# Pt–CeO2
# Ion Beam Sputtered
# (1−
# Y)Fe2(SO4)3
# +
# YH2SO4
# Photocurrent Transient Response
# Global Buckling
# BS40
# Cathode Contact
# Interfacial Viscosity
# Spectroscopic Plots
# VB1
# A-d-a
# Denitrification Performance
# Drug Development
# Substitutional Defects
# Ti-HA
# LGP
# Non-Hygroscopic
# Ankle Joint Angles
# Digital Pressure Transducer
# Oven Ageing
# Fractal-Like
# Fired Thermal Power Plants
# Flocculation Kinetics
# I01
# Power Management Strategy
# Passivation Treatment
# Load and Resistance Factor Design
# Edge Correspondence
# SnO2 Sb2O3
# Carbon Deposition Resistance
# Isoconversional Analysis
# Electrochemical Images
# Nanocore
# Pin-Hole Free
# Solution Interface
# Transcutol
# F(η)
# Passive Safety Features
# ...
# Fgr
# DMAN
# Ti–22Al–27Nb
# Electrodialyzed
# Non-Radiative Recombination Losses
# Digital Pulse Shape Analysis
# 4-PCPTC
# CO2/H2O Selectivity
# C 60 Fullerene
# Thickness Profile
# Ag+ Detection
# Neutron Converter
# Chloromethylstyrene
# Subsistence
# Wing Tip Frequency Response
# Forest Productivity
# Electroretinography
# Geopotential Meters
# Vapor Pressure Errorep, VPWIN
# Cyclic Disulfide
# Sn(l)
# 42CrMo4
# 209GPa
# COSMO-SAC
# NdCrO3
# CO2 Rate
# Hydroxyl O
# Rami
# Tetraethylene Glycol Monododecyl Ether
# Merwinite
# Doa
# Ce3+,Yb3+
# HF-CVD
# Water Reclamation
# Age Histograms
# Dialkyl Carbonates
# Open Sun Drying
# Photo-EPR
# Cu-EDTA
# Center Manifold Theorem
# Poly-Lysine
# 57Fe-M
# Photo Polymerization
# HCV Infection
# Alkali-Resistant
# Herington Method
# Snk Test
# MM2
# Cis-Cyclooctene Oxidation
# 8-Bromo-cGMP
# Coenzyme Q
# Diphosphates
# Renewable Energy Supply
# Pseudo-Two
# D=30
# Iron Disulfide
# 2D Fast Fourier Transform
# Microcontact
# Densite
# Breakdown Characteristics
# ATP Hydrolytic Activity
# Unpaired Student's T Test
# Leucogranitic
# Naphthoquinones
# Class Variance Criterion
# N2 and CH4
# Wireless Applications
# 1D Tubular
# Laminated Cylindrical Shells
# PtdIns(4,5)P2
# - Resolved Photoresponse
# Fume
# TASS
# Diastolic Function
# Pyrometry
# Jump Ratio μ−
# Iron Arsenides
# Electrochemical Research
# XCOM Program
# Etravirine
# U B
# Biosorption Efficiency
# Ti-Si-C
# Vess
# Desalinated Water
# In-Plane Uniaxial Anisotropy
# Operator
# NiMoS4
# Zn–40Al–2Cu–2Si
# PVC–LiCF3SO3–SiO2
# Absorption and Emission
# CO+NO
# Oxygen Surface Exchange Rate
# Morphological Phase Diagram
# Pt{1 0 0}
# First-Principles Modeling
# Spin Imbalance
# Jellyroll
# 2-Bromopropene
# MnPd
# Fluorescence QY
# Electrode Binder
# TBATPBCl
# Antinociception
# VIES
# Tb-BMO
# 2,3-Dimercaptosuccinic Acid
# Relaxometric Properties
# Severely Deformed
# Superhydrophilic Property
# Supraparticle
# Retracker
# Preferential Oxidation Reactor
# CpG-ODN
# CoSn5
# Decarboxylative
# Compression Yield Strength
# Dynamical Structure Factor
# VPBA
# Local Electronic Properties
# Fed-Batch Ssf
# Pba2
# LiNi0.4Mn0.4Co0.2O2
# Planarization Efficiency
# FeCl2(2)
# Selective Epitaxial Growth
# Cd) Spectroscopy
# Propylene Glycol Monomethyl Ether
# A-Co3O4
# Graphenylene
# Dislocation Gliding
# Blade Element Momentum Theory
# ESOP
# Fish Farm
# 2-Co
# Cobalt Diselenide
# Extension Test
# Microbial Community Diversity
# Anticorrosion Efficiency
# Thermal Comfort Zone
# ECL Emitter
# (B) Oxygen
# Nanoscale Bicrystal
# Vertical Advection
# Sodium - Sulfur
# Anti-Aging Performance
# Isoindole
# Major Element Concentrations
# Mercurochrome
# Polyarylene Ether Nitrile
# Plasmonic Characteristics
# FAEEs
# Radicicol
# JT Distortion
# Pre-Magnetization
# TVA
# Plasma-Based
# Texturally
# MgIn2O4
# Drinking Purposes
# Fluidization Characteristics
# Propane Partial Oxidation
# Scientific Applications
# Dithieno[3,2-b:2',3'-d]pyrrole
# Fc-D
# Oxygen Plasma Assisted Molecular Beam Epitaxy
# Stick-Slip Friction
# 5CuO
# DLIP
# Pd–Mn3O4
# Photovoltaic (PV) Devices
# Zinc Chloride (ZnCl2)
# N1888][NTf2
# GC/C/
# Aerogel Scaffold
# Plant Communities
# Redispersibility
# CDA
# Dewetting Kinetics
# Ave
# Granulates
# Synchrotron X-Ray Absorption Spectroscopy
# B3LYP/3-21G(*)
# Lanthanum(III)
# 16S rDNA
# Fluctuation Electron Microscopy
# Laminated Object Manufacturing
# Solubility of Carbon Dioxide
# Oligodeoxyribonucleotides
# Localized Electrochemical Impedance Spectroscopy
# Solid State Diffusion Method
# Melt Pool
# MP2(Full)/6-31G*
# Tpcd
# Remanent
# Direct Stochastic Optical Reconstruction Microscopy
# Biodegradation Kinetics
# Virial Method
# 2,4-DP
# Flux Profiles
# Enzymolysis
# Lipofectamine 2000
# Lanthanum Manganate
# OSL Dosimetry
# Epileptogenesis
# Copper–Iron
# Ultra-High-Performance Liquid Chromatography
# Oxygen Response
# TOPAS Program
# Desilication Treatment
# Olefination
# Flow Model
# Hydrated Oxide
# Supercooling
# Binding Energy Calculations
# Language
# UCPL
# Uninterruptible Power Supply
# Kahweol
# GC Content
# Stomatal Aperture
# Maeam
# Specific Reactivity
# 4-31G
# Physiological Properties
# Na2SO4(2)
# Proximate Composition
# S PANi
# Microfluidic Structures
# Pt–RuO2
# Cross Sectional EBSD
# Tetracyanoethene
# Cholera Toxin B Subunit
# Magnetic Information
# Third-Order NLO Properties
# PCL-Hydro
# Amc
# Redox Current Density
# Finite Cell Method
# 13C–1H
# N-Carbon
# ZrO2-P
# High-Resolution Powder Neutron Diffraction
# Catalytic Oxidation of SO2
# Sec-Butyl
# NH4CO2H
# Koutecky - Levich Analysis
# EDAC Pd(0)
# Probe Structure
# Vinylferrocene
# Cholinergic Neurotransmission
# Sedimentation Behavior
# Direct Compression
# Oxidation Temperature
# 1,3-Dialkylimidazolium
# Ethyl Vinyl Ketone
# DIII-D Tokamak
# DSNCS
# Core - Shell Nanocables
# F OW
# Entrainment
# Face-Sheets
# Poly(ADP-Ribose) Polymerase
# Organometallic Chemical Vapor Deposition
# Conventional Furnace
# Real Power
# Lyso
# Ground Spin State
# ππ*
# Phase Interface
# Bloom
# Starpeg
# MoNi4
# Hydroxycarbonylation
# Tpeak
# Thematic Mapper Plus
# Ann-
# Dialdehydes
# SHCC
# Ethanediol
# A*T
# ECOFOCI
# Acquired Immune Deficiency Syndrome
# PVP-I
# Sono-Sulfated
# η λ
# Information Content
# UTL
# Three Dimensional Microstructure
# Photo-Excited Electrons
# Ti–47Al–2Cr–2Nb Alloy
# Acceptor Emission
# Vertical Absorption
# Mode Confinement
# ATAC-Seq
# C10E8
# Metal Particle
# Tree Topology
# Hampshire
# Powder Metallurgy Processing
# Ground-State Degeneracy
# σ θθ
# Food Samples
# Photocatalytic Field
# Amino Trimethylene Phosphonic Acid
# Density Porosity
# Cu–10Sn
# Bis(Trifluoromethylsulfonyl)amide
# Structure Ordering
# Reductive Electropolymerization
# Linearized Augmented Plane Wave
# Electrooxidized
# Mesoporous Nanowires
# Environmental Loads
# singlet oxygen sensor green
# Magnetorheological Elastomers
# Benzo(g,h,i)perylene
# Bimodal Imaging
# Methyl Phenyl Sulfone
# Height Profile Diagram
# IPN Films
# UTSA-16
# CO2 Outlet Concentration
# Water Absorption Behavior
# Photo-Physical
# Fluoroarenes
# Surface Oxygen Exchange Kinetics
# Tool Coatings
# Weno-Symoo
# Forming Load
# Phase Slips
# RNAi Therapeutic
# Capture Plants
# LED Screen
# Time-On-Stream Activity
# Molecular Diameter
# Boundary Integral Equation Method
# Diffusion Distances
# Coastal Management
# Stannic Oxide
# Metal Recovery
# LUFA
# Basal Texture Intensity
# D Spins
# Neutrino Flux
# Ir(210)
# Configurational-Bias Monte Carlo Simulations
# Plasma Half-Life
# HFPA
# Yb3+-Er3+
# Solid Oxide Electrochemical Cells
# S-1
# Deae-Sepharose
# Sandwich-Type Electrochemiluminescence
# Three-Dimensional Simulation
# LiBEt3H
# Nissan
# Ice Nucleation
# Greigite
# (CH3NH3)3Bi2I9
# Electrophoretic Properties
# LSDA + U
# Critical Electric Field
# TiCaPCON
# GCGC
# Glew
# Micromanipulation
# N-Acetyl-Cysteine
# Impact Time
# Bs0-μ+μ
# Dipyrromethene
# B-Casein
# Thermostat
# Geomagnetic Field
# HCCCH2Br
# Oestradiol
# CaCO3-PAA
# Transverse Relaxation
# Dot Height
# Mott-Hubbard
# Zinc Niobate
# Apparent Molar Isentropic Compression
# Bet Specific Area
# Carbon Combustion Synthesis
# Percolation Temperature
# PPhMe2
# ANSYS Fluent 14.0
# Release Time
# Mo(Si,Al)2
# Central Age Model
# EV Battery
# Nanorods/Graphene
# Cradle-to-Gate Life Cycle Assessment
# Clpso-ML
# Li[Li0.2Ni0.2Mn0.6]O2
# Mixed-Voltage I/O Circuits
# Columbamine
# 6-311+G(2df)
# Monzodiorite
# Hyperbolic Sine Function
# Lamellar Liquid Crystal
# Magnetostriction Constant
# Fluoroform
# High-Energy Milled
# EAOP
# Concentration C 0
# Percolation Concentration
# H 3/E
# Spin-Down Currents
# Micellar Morphology
# SiB6
# Boiler Furnace
# Proton Pump Inhibitors
# Quadrupole Coupling
# THF,80C
# Detection of Ethanol
# SOFC-PEFC
# Photocatalytic Hydrogen Production From
# Conductive Geotherms
# Petal Effect
# Pliocene-Pleistocene
# Se K
# Methanesulfonate
# Modulation Vector Q
# CHOP
# Life Times
# -LaFeO3
# 17-4PH Steel
# Inhibitory Properties
# Pentan-3-one
# PMMA-G
# Prestress
# Niobium Oxide (Nb2O5)
# PLA-b-MPEG
# Microspindles
# Post-Peak
# Elastic Compliance
# 1,2-Bis(Trimethoxysilyl)ethane
# N Si/N Al Ratios
# Ru(1)-P(1)
# Swh
# Electronic Dispersion
# Uranium Vacancies
# Ultrafiltration (UF) Membranes
# Magnetic Isotropic Shielding Constants
# Batch Extraction
# Pd/A
# Eu2O3 Content
# Motorcycle Helmet
# Chronic Heart Failure
# GC-AED
# Nuclear Forensics
# Surface-Aligned
# Hyperspectral Infrared Imager
# HCD-IP
# YSR
# Cell Uptake Behavior
# Higher Order Curved Beam Theory
# D-Psicose
# Heat Stress
# Bond Valence Calculations
# Barium Cerate
# Radiative Losses
# Hitec
# ZIC
# Amorphous Surface Layer
# TosOH
# Ni(OAc)2
# Sorption Capability
# Uniaxial Compressive
# AFM Topographic Image
# Prepared Composite
# NaDyF4
# Burn Duration
# H2 Evolution Mechanism
# Semiconductor Property
# MnC
# Fuel-NO
# Seps
# Betweenness Centrality
# Multislice ADF-STEM Image Simulation
# 3.2
# EOC
# Power Capabilities
# Restoration Mechanism
# Hybrid Microparticles
# Conductive Behavior
# Antifouling Characteristics
# Silica Calcium Aluminosilicate
# Variable Speed Stirrer
# VDW - DF2
# Striatal Slices
# Bonded Particle Model
# Cyclopentenones
# Prox Activity
# OFO Xylene
# Mechanically Affected Zone
# Al2O3–H2O
# Dsifs
# H2 Storage Applications
# Spatial Plots
# SPD Processing
# Immunoreactivities
# Bright Field Transmission Electron Micrographs
# Toric
# Graphene-1
# Propane-1,2-Diol
# Ray Compositional Maps
# PyMDMA
# FEMS
# Na2SO4+ H2O
# Fe(III)EDTA
# TZ6
# DMPO O2
# Cyclic Voltammetric Curve
# 4-Fluorophenylboronic Acid
# Methane+Water+Diesel Oil
# 3DOM-TiO2-S
# Master Equations
# HR9
# Shear Locking
# 1,1′-Carbonyldiimidazole
# Nanosphere Arrays
# Fear Memory
# Coherence Squared
# Medicinal Applications
# Kinematic Hardening
# 11-MUA SAM
# PECVD,
# PEG2K
# Log KOA
# σ xx f
# Nano-CT
# TiO2-200
# CTF
# Hood
# Cuckoo
# Fishway
# Ahr
# CRTA
# RGO2
# 2,3-DMP
# Ultrasonic Deposition
# R 2 Relaxivity
# HCl+
# Renal Cell Carcinoma
# Bulk Heterojunction Photovoltaic Cells
# Calcium-Aluminate
# ZABs
# Electrochemical Conversion of
# KSAc
# Europium Nitrate
# Sodium 4-Styrene Sulfonate
# Non-Ohmic Properties
# B1g
# Embankment Stability
# Microstructural Instability
# Wannier Functions
# Acoustic Emission (
# Energies of Formation
# Neuromuscular Junction
# Methanol Oxidation Current Density
# MeCl
# Spectral Induced Polarization
# JPC
# AA5086
# Operando Drifts
# NPHI
# Dimethyl Succinate
# Δ2HCH4
# Mℓ
# Pleated
# O2-Annealing
# Iedda
# TMU
# Meth
# [EMIm]Br
# Phylogeny
# SU
# RAFT Aqueous Dispersion Polymerization
# Terrestrial Ecotoxicity Potential
# Irtf
# σ B 2
# Isobaric Thermal Expansivity,P
# 2-Methoxy-2-Methylpropane
# Theranostic Systems
# 95C
# Endurance Limits
# Transverse Spin Current
# 800MPa
# Coal P
# Hydroesterification
# C4H6O6
# TRITON-X-100
# Thermal Cycling Lifetime
# NaTf
# Low-Magnification HAADF-STEM
# Dealkylation
# 2H WS2
# Tb-MOF
# Nafion®-Coated
# Molecular Chains
# σYZ
# Incompatible Element
# Planar Averaged Charge Density Difference
# AP1000
# Sealer
# Extinction Coefficient K(ω)
# Graphitic-Nitrogen
# Slide Angle
# Molecular Materials
# F-T
# ZnO-Au
# Color Range
# Pasting Viscosity
# High-Resolution O 1s XPS
# PHA Content
# Ring Imaging Cherenkov
# Iron Nitrides
# Galvanostatic Techniques
# Ceramic Particulates
# Positive Ion Multiple Reaction Monitoring
# 1-Phenylethane-1,2-Diol
# PGlu
# HO Concentration
# Electron Spin Resonance Analysis
# NBI
# Soil Organic Carbon Density
# Brittle-To-Ductile Transition Temperature
# 2 kPa H2O
# Annihilation Cross Section
# C-36
# Partings
# Hydrostatically Extruded
# Mass Selective Detector
# 1-Bromobutane
# [Ni2L3]4+
# Three - Dimensional ( 3D
# Lateral Correlation Length
# Fukui
# Trimethylethoxysilane
# Hydrogen Generation Performances
# Fatigue Damage Accumulation
# Agnp
# Gd2O(CO3)2 H2O
# DAU
# Rectifying Properties
# Mesopore Walls
# Leaded Gasoline
# Fractograms
# DFD
# Thermally Stratified
# HESS
# Photoelectrochemical Analysis
# PJ-34
# Operators
# AMU
# Immunolabeled
# Strength of
# Silica Agglomerate
# Porous 2D
# Agostic
# MRPC
# Deep Convolutional Neural Network
# MIR Spectral Imaging
# Li2Gd4(MoO4)7
# B3LYP/6-31G* Method
# Liquid Cell Transmission Electron Microscopy
# Brain MRI
# Cubic PM3M
# Linear IR Absorption Spectra
# Time-Dependent1H
# Oxygen Evolution Reaction Overpotential
# Film Nanostructure
# FMOLS
# 1H2O
# Stiffness Model
# U 4
# Seismic Isolation
# C240
# SiO2-NR
# Network DEA
# Torsions
# Nanoleakage
# Drain Conductance
# CF3C(NPh)Cl
# LCMP-β-CD-ASWCNTs
# Σ-
# H-MCM-41
# Ansa-Metallocene
# Total Factor Productivity
# Mg50Ti50
# ZOH
# Hydrogen Compressor
# Valsartan
# NMOR
# ROI Analysis
# Mathematical Analysis
# Carbonyl Emissions
# Engine Performance Parameters
# Oxazaborolidine
# SiO2 HM SO3H
# GPPEC
# Third
# Δ S
# Layered Ceramics
# Electrochemical Noise Analysis
# Planar Technology
# CVD-Coated
# 3D-NPC
# Admittance Nyquist Diagram
# CellQuest Software
# In2O3-H
# ε0
# Carbon Dioxide Permeance
# 1,2-Difluorobenzene
# BSTract Two
# δ15NNO3
# External Calibration
# Columnar Hexagonal
# Bi 2 Sr 2 CaCu 2 O x
# Hormones
# NVO
# Energy Justice
# Physical Methods
# Radon Chamber
# Water-Gas-Shift
# Second-Order Calibration
# Mechanical Shaking
# Zoning Profiles
# Ultrasonic Melt Treatment
# Network Glasses
# Reactive Molecular Dynamics Simulations
# Carboxylated Multiwalled
# Heave Damping
# Calorimetric Techniques
# Plate Theories
# Ridge Max Analysis
# Al Kα
# Spin-Polarized Calculations
# Sqct
# Κ2
# EBCT
# Open-Cell Structure
# Hydrate-Based
# Glass Mat
# CRISPR-Cas
# Load-Bearing Structures
# Metal Protection
# Paintability
# Near-α
# Electrochemical Cyclic Voltammetry
# BLDC
# Genome Engineering
# Skew Scattering
# Clamped Beam
# Axial Residual Stress
# Photoelectric Conversion Performance
# Au(310)
# Oxygen Etching
# Alcoholate
# Nht
# Acesulfame-K
# Superradiance
# DACHPt
# TAN Concentration
# Reversible Hydrogen Storage
# Temperature - Dependent Sorption Isotherms
# TSIL
# Transfer Method
# Glutathione S-Transferase Activity
# 3D Tissue
# Photocatalytic Procedure
# Manipulation
# Multi-Effect Distillation
# Metal Mould Casting
# Magnetic Excitation Spectrum
# PbZrXTi1-XO3
# Polarization Mechanism
# HNS
# Copper Aluminate
# Polariton Modes
# 1,8-Naphthalimides
# 1,3-Hydrogen
# Electrode Wear Ratio
# RC2
# Sized Precipitates
# Polarization Fatigue
# Implant Stability
# Diffusion Mobility
# Albendazole
# A-Diimine
# Sub-Shell X-Ray Production Cross Sections
# Maximum Surface Excess
# TRIS-GO
# Magnetization Loss
# DSPM
# Alkali-Ion Batteries
# Y H 2
# Direct Ammonia Fuel Cell
# BCC.
# Electroless Etched
# Active Magnetic Regenerator
# SSOFs
# Arylthiol
# Alkali Metal Ion Batteries
# Nucleation Frequency
# Bz-Ep
# DIBAL–H
# ZnO-B2O3
# Radiative Divertor
# S T R A C T AN
# Dengue
# TRA
# Receptive Fields
# 4-Bromobenzyl Bromide
# Uniaxially Oriented
# Hybrid Systems
# Weno-Z
# 3,3-Dimethylpentane
# Boc Anhydride
# Crude
# Disulfide Connectivity
# Nanocrosses
# Receptor α
# Citrate-Nitrate
# HoNi2
# Second-Order Difference of Energies
# Beam-Column Connection
# Dmphen
# N/m*
# Supramolecular Self-Assembly
# Wirelike
# Potential Electrodes
# Kurtz - Perry Method
# Glare
# Sponge Layer
# Tetraalkoxysilanes
# Gd-Tm
# Lithium-Polymer Battery
# CE-LIF
# Passivation Effect
# Peltier
# Gap Junction
# PDBu
# Von Mises Stress σ Eqv
# SiO2(2)
# Stearyl Alcohol
# Hard-Carbon
# Oxidative Alkenylation
# Scanning Acoustic Microscope
# Color Development
# τ α
# Dc-Pecvd
# SE Image
# Radiogenic Heat Production
# Oligo(Poly(Ethylene Glycol) Fumarate)
# D+Au
# Application Specific Integrated Circuits
# Intcal04
# Hydrogel Tube
# Thermal Entropy Generation
# Pd/CB
# TCSA
# Orbital Reconstruction
# Ni-B-TiO2
# GB Dislocations
# Ground-State Spin
# Hot-Cast
# Zn–Ni
# Regression Rate
# Nuclear Spin-Lattice Relaxation Rate
# Ura
# GP2
# Gel-Sol
# +ATP
# Imine Hydrogenation
# Diethyl Ether,78C
# High-Pressure X-Ray Diffraction
# Gisans
# Trichloronitromethane
# Furfuryl Propionate
# Hydroxyeicosatetraenoic Acid
# Halogen-Free
# Zero-Field μSR
# Co-Sensitized Solar Cell
# Eu Concentrations
# Cerium Content
# Boltzmann Plot
# μ-SXRF
# Bio-Rejuvenated
# CH2NH
# Spin Coherence Time
# Resazurin Reduction Assay
# PEM;
# AC Magnetization Measurement
# Cu(OH)2 NA
# O-CeO2
# Tectonic Domains
# Catalyzed Carbonylative Synthesis
# ZrB2–20vol
# DCPC
# Storage Battery
# Occupant Health
# Swimming Pool Water
# -Ga2O3
# Periphyton
# 17-DMAG
# Fenton's Oxidation
# Sequential Gravity Cast
# Explained Variance
# Co-Stabilized
# Headspace Gas Chromatographic
# Vertical Tube
# VCS-Langmuir Model
# Air Quenching
# Racemic Blends
# Water Management System
# Hydrogenation Characteristics
# Radiofrequency Furnace
# Boiling Water Treatment
# FD4
# PFB-Br
# 31P MAS
# Spin Dephasing
# Dec-1-ene Epoxide
# Oxygen Chemical Diffusion Coefficient
# Tetrabutyl Ammonium Bromide
# Infrared Brazed
# LiMn1 -x Cr x O2
# Of Carbon
# Orbital Degeneracy
# Chromatographic Retention
# Mean Free Energy
# BEAV
# Tadpoles
# Anemia
# Chronologies
# Signal to Noise (S/N) Ratios
# Jcp2
# CCh
# Autocatalytic Model
# Biofuel Crops
# Laser Doppler Velocimeter
# Hygrothermal Performance
# Electrostatic Induction
# Zeolitized
# Natural Capital
# FeFe Distances
# GPER
# FeOF
# Ray CT
# Reservoir Engineering
# Pd–Bi
# Single Particle Spectroscopy
# Laue
# MEAM
# As-Prepared-MNO2
# Tertiary Homoallylic Alcohols
# Normal-Strength
# Specific Entropy Generation Rate
# 5d0 Quantum Efficiency
# Calculated 1H
# Grinding Force Ratio
# PFZH-25
# Cylindrical Charge Explosion
# Sorption Affinity
# Perovskite A
# Cesm
# Geopotential Harmonics
# Optical Yield
# Ω 0
# Au MnO2
# CuO–ZrO2
# 2-Mercapto-1-Methylimidazole
# O2 Production Rate
# SLPS
# σ H
# Magnesium Silicate Perovskite
# Vanadium Ion Concentration
# Manganosite
# CH2(CO2Et)2
# Anisotropic Wet Etching
# AlH3-Etherate
# PLGA7510
# Diagnostic Purposes
# Damping Behaviour
# TCNQ2

# %%
count
# Out:
# 81518

# %%
# Adding this data to the DataFrame
ENTDOI['Preferred_Entity'] = ENTDOI['Preferred_Entity'].apply(lambda x: mapping_dict[x] if x in mapping_dict else x)

# %%
ENTDOI.to_csv('ENTDOI.csv', index = None)

# %%
def sanitize_entity(entity):
    return quote(entity)

# %%
ENTDOI.head()
# Out:
#                                       Entity Part_of_text NER_Tag  \
# 0  electrospray ionization mass spectrometry          Abs     APL
# 1                                       wsoc          Abs     APL
# 2                                 pyridinium          Abs     APL
# 3                                  navy blue          Abs     APL
# 4                                gantt chart          Abs     APL
#
#                               DOI                           Preferred_Entity  \
# 0   10.1016/s0925-4005(02)00161-2  Electrospray Ionization Mass Spectrometry
# 1  10.1016/j.atmosenv.2007.06.034                                       WSOC
# 2               10.1021/jo0712401                                 Pyridinium
# 3   10.1016/j.ecoleng.2013.07.005                                  Navy Blue
# 4               10.1021/ie970286p                                Gantt Chart
#
#      Year
# 0  2002.0
# 1  2007.0
# 2  2007.0
# 3  2013.0
# 4  1997.0

# %%
NER, pref_entity = ENTDOI[['NER_Tag', 'Preferred_Entity']].values.T

# %%
len(NER), len(pref_entity)
# Out:
# (84659831, 84659831)

# %%
# Dictionary to keep track of entity URI mappings
entity_uri_mapping = {}

for ner, pref_ent in tqdm(zip(NER, pref_entity), total = len(NER)):
    if pref_ent:

        # Add Preferred_Entity, creating a URI based on NER tag
        preferred_entity_uri = URIRef("http://example.com/{}/{}".format(ner, sanitize_entity(pref_ent)))

        entity_uri_mapping[pref_ent] = preferred_entity_uri
# Out:
# 100%|██████████| 84659831/84659831 [02:59<00:00, 471315.03it/s]

# %% [markdown]
# ### Creating RDF Dataset

# %%
# Create a RDF graph
# Create an empty RDF graph
g = Graph()

# Define namespaces
n = Namespace("http://example.com/")
doi = Namespace("https://doi.org/")
entity_uri_dict= {}

# Iterate through each row in the DataFrame to create RDF triples
for index, row in tqdm(ENTDOI.iterrows(), total = ENTDOI.shape[0]):
    
    if any(pd.isnull(row)):
        continue
    
    
    try:
        node_uri = URIRef(f"http://example.com/row{index}")

        # Add Entity
        g.add((node_uri, n.hasEntity, Literal(row['Entity'])))
        
        # Add Part_of_text
        g.add((node_uri, n.partOfText, Literal(row['Part_of_text'])))

        # Add NER_Tag
        g.add((node_uri, n.hasNER_Tag, Literal(row['NER_Tag'])))
        


        # Add DOI, encoding it first
        encoded_doi = quote(row['DOI'])
        doi_uri     =  URIRef(f"https://doi.org/{encoded_doi}")
        g.add((node_uri, n.hasDOI, doi_uri))
        # Add Year to DOI       
        g.add((doi_uri, n.hasYear, Literal(row['Year'])))
        
        # Add Preferred_Entity, creating a URI based on NER tag
        preferred_entity_uri =entity_uri_mapping[row['Preferred_Entity']]
        g.add((node_uri, n.hasPreferredEntity, preferred_entity_uri))
        entity_uri_dict[row['Preferred_Entity']] = preferred_entity_uri
        
        if (index+1)%10000000==0:
            g.serialize(destination='ENTPTNERDOI.nt', format='nt')
    except Exception as e:
        print(e)
        pass

g.serialize(destination='ENTPTNERDOI.nt', format='nt')
# Out:
#  12%|█▏        | 9999986/84659831 [35:49<3:47:19, 5473.88it/s] /home/synthesisproject/anaconda3/envs/vineeth_10/lib/python3.10/site-packages/rdflib/plugins/serializers/nt.py:40: UserWarning: NTSerializer always uses UTF-8 encoding. Given encoding was: None
#   warnings.warn(
#  37%|███▋      | 31587540/84659831 [2:21:34<2:46:09, 5323.66it/s] IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
#  47%|████▋     | 39430092/84659831 [3:10:26<3437:59:36,  3.65it/s] IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
print("Done")
# Out:
# Done
